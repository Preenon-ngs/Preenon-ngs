# %% [markdown]
# <a href="https://colab.research.google.com/github/Preenon-ngs/Preenon-ngs/blob/main/Charakfinal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install PyMuPDF

# %%
import fitz  # PyMuPDF
from PIL import Image
import os

def pdf_to_images(pdf_path, output_folder):
    # Open the PDF
    pdf_document = fitz.open(pdf_path)

    # Create the output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # Iterate over each page in the PDF
    for page_number in range(len(pdf_document)):
        # Get the page
        page = pdf_document.load_page(page_number)

        # Render the page as an image (high resolution)
        image = page.get_pixmap()

        # Convert to PIL Image
        img = Image.frombytes("RGB", [image.width, image.height], image.samples)

        # Save the image as JPG
        image_path = os.path.join(output_folder, f"page_{page_number + 1}.jpg")
        img.save(image_path, "JPEG")

    # Close the PDF
    pdf_document.close()

# Path to the PDF file
pdf_path = "/content/CharakSamhitaAtridevajiGupt.pdf"
# Output folder to save images
output_folder = "/content/drive/MyDrive/pdf to image"

# Convert PDF to images
pdf_to_images(pdf_path, output_folder)

# %%
# !pip install pytesseract

# %%
import os
os.kill(os.getpid(), 9)

# %%
# Install Tesseract OCR and language packs
# !sudo apt install tesseract-ocr
# !sudo apt install tesseract-ocr-sans
# !sudo apt install tesseract-ocr-hin
# !pip install pytesseract

# %%
# !mkdir /content/drive/MyDrive/output2.txt

# %%
import os
from PIL import Image
import pytesseract
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')

# Path to the folder containing images
image_folder_path = '/content/drive/MyDrive/pdf to image'

# Path to Tesseract executable
pytesseract.pytesseract.tesseract_cmd = r'/usr/bin/tesseract'

# Function to extract text from an image
def extract_text_from_image(image_path):
    image = Image.open(image_path)
    text = pytesseract.image_to_string(image, lang='hin+san')
    return text

# Function to save text to a file
def save_text_to_file(text, file_path):
    with open(file_path, 'w', encoding='utf-8') as file:
        file.write(text)

# Iterate over images in the folder
for filename in os.listdir(image_folder_path):
    if filename.endswith('.jpg') or filename.endswith('.png'):
        image_path = os.path.join(image_folder_path, filename)
        text = extract_text_from_image(image_path)
        text_file_path = os.path.join('/content/drive/MyDrive/output2.txt', filename.split('.')[0] + '.txt')
        save_text_to_file(text, text_file_path)
        print(f"Text extracted from {filename} and saved to {text_file_path}")
