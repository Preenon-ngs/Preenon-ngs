# %% [markdown]
# # Metagenomics Basic Analyses
#
# ## Metagenomics Data Analysis: Diversity and Ordination
#
# This is a comprehensive notebook for performing a preliminary analysis of gut metagenomic data from the Human Microbiome Project 2 (HMP2) to explore microbial community structure, focusing on **alpha diversity** and **beta diversity** in relation to Inflammatory Bowel Disease (IBD) diagnosis (Crohn's Disease (**CD**), Ulcerative Colitis (**UC**), and **nonIBD** controls).
#
# We will use the Python library **`scikit-bio`**, a bioinformatics package that provides functions for diversity analysis (alpha and beta) and ordination methods like Principal Coordinate Analysis (PCoA).

# %%
# !pip install scikit-bio git+https://github.com/Multiomics-Analytics-Group/vuegen.git@loosen_versions
# Out:
# Collecting git+https://github.com/Multiomics-Analytics-Group/vuegen.git@loosen_versions
#   Cloning https://github.com/Multiomics-Analytics-Group/vuegen.git (to revision loosen_versions) to /tmp/pip-req-build-e98kev8t
#   Running command git clone --filter=blob:none --quiet https://github.com/Multiomics-Analytics-Group/vuegen.git /tmp/pip-req-build-e98kev8t
#   Running command git checkout -b loosen_versions --track origin/loosen_versions
#   Switched to a new branch 'loosen_versions'
#   Branch 'loosen_versions' set up to track remote branch 'loosen_versions' from 'origin'.
#   Resolved https://github.com/Multiomics-Analytics-Group/vuegen.git to commit 17ce3cc7247684856cbe4ed1da62cabdf7d72971
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting scikit-bio
#   Downloading scikit_bio-0.7.1.post1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (9.7 kB)
# Requirement already satisfied: requests>=2.20.0 in /usr/local/lib/python3.12/dist-packages (from scikit-bio) (2.32.4)
# Requirement already satisfied: decorator>=3.4.2 in /usr/local/lib/python3.12/dist-packages (from scikit-bio) (4.4.2)
# Requirement already satisfied: natsort>=4.0.3 in /usr/local/lib/python3.12/dist-packages (from scikit-bio) (8.4.0)
# Requirement already satisfied: numpy>=2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-bio) (2.0.2)
# Requirement already satisfied: pandas>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from scikit-bio) (2.2.2)
# Requirement already satisfied: scipy>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from scikit-bio) (1.16.3)
# Requirement already satisfied: h5py>=3.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-bio) (3.15.1)
# Collecting biom-format>=2.1.16 (from scikit-bio)
#   Downloading biom_format-2.1.17-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.0 kB)
# Requirement already satisfied: statsmodels>=0.14.0 in /usr/local/lib/python3.12/dist-packages (from scikit-bio) (0.14.5)
# Requirement already satisfied: patsy>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from scikit-bio) (1.0.2)
# Collecting array-api-compat>=1.3 (from scikit-bio)
#   Downloading array_api_compat-1.12.0-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: altair[save] in /usr/local/lib/python3.12/dist-packages (from vuegen==0.5.1.post4.dev0+17ce3cc) (5.5.0)
# Collecting dataframe-image<0.3.0,>=0.2.6 (from vuegen==0.5.1.post4.dev0+17ce3cc)
#   Downloading dataframe_image-0.2.7-py3-none-any.whl.metadata (9.3 kB)
# Collecting itables<3.0.0,>=2.2.2 (from vuegen==0.5.1.post4.dev0+17ce3cc)
#   Downloading itables-2.5.2-py3-none-any.whl.metadata (10.0 kB)
# Collecting kaleido<0.3.0,>=0.2.0 (from vuegen==0.5.1.post4.dev0+17ce3cc)
#   Downloading kaleido-0.2.1-py2.py3-none-manylinux1_x86_64.whl.metadata (15 kB)
# Requirement already satisfied: matplotlib<4.0.0,>=3.9.2 in /usr/local/lib/python3.12/dist-packages (from vuegen==0.5.1.post4.dev0+17ce3cc) (3.10.0)
# Requirement already satisfied: nbclient<0.11.0,>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from vuegen==0.5.1.post4.dev0+17ce3cc) (0.10.2)
# Requirement already satisfied: nbformat<6.0.0,>=5.10.4 in /usr/local/lib/python3.12/dist-packages (from vuegen==0.5.1.post4.dev0+17ce3cc) (5.10.4)
# Requirement already satisfied: openpyxl<4.0.0,>=3.1.5 in /usr/local/lib/python3.12/dist-packages (from vuegen==0.5.1.post4.dev0+17ce3cc) (3.1.5)
# Requirement already satisfied: plotly<6.0.0,>=5.15.0 in /usr/local/lib/python3.12/dist-packages (from vuegen==0.5.1.post4.dev0+17ce3cc) (5.24.1)
# Collecting pyvis<0.4.0,>=0.3.2 (from vuegen==0.5.1.post4.dev0+17ce3cc)
#   Downloading pyvis-0.3.2-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: pyyaml<7.0.0,>=6.0.2 in /usr/local/lib/python3.12/dist-packages (from vuegen==0.5.1.post4.dev0+17ce3cc) (6.0.3)
# Collecting quarto-cli (from vuegen==0.5.1.post4.dev0+17ce3cc)
#   Downloading quarto_cli-1.8.26.tar.gz (4.6 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting streamlit<2.0.0,>=1.39.0 (from vuegen==0.5.1.post4.dev0+17ce3cc)
#   Downloading streamlit-1.51.0-py3-none-any.whl.metadata (9.5 kB)
# Collecting streamlit-aggrid (from vuegen==0.5.1.post4.dev0+17ce3cc)
#   Downloading streamlit_aggrid-1.2.0.post1-py3-none-any.whl.metadata (10 kB)
# Collecting vl-convert-python<2.0.0,>=1.7.0 (from vuegen==0.5.1.post4.dev0+17ce3cc)
#   Downloading vl_convert_python-1.8.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.2 kB)
# Requirement already satisfied: xlrd<3.0.0,>=2.0.1 in /usr/local/lib/python3.12/dist-packages (from vuegen==0.5.1.post4.dev0+17ce3cc) (2.0.2)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from biom-format>=2.1.16->scikit-bio) (8.3.0)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.12/dist-packages (from dataframe-image<0.3.0,>=0.2.6->vuegen==0.5.1.post4.dev0+17ce3cc) (7.16.6)
# Requirement already satisfied: aiohttp>=3.10.2 in /usr/local/lib/python3.12/dist-packages (from dataframe-image<0.3.0,>=0.2.6->vuegen==0.5.1.post4.dev0+17ce3cc) (3.13.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from dataframe-image<0.3.0,>=0.2.6->vuegen==0.5.1.post4.dev0+17ce3cc) (11.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from dataframe-image<0.3.0,>=0.2.6->vuegen==0.5.1.post4.dev0+17ce3cc) (25.0)
# Requirement already satisfied: mistune in /usr/local/lib/python3.12/dist-packages (from dataframe-image<0.3.0,>=0.2.6->vuegen==0.5.1.post4.dev0+17ce3cc) (3.1.4)
# Requirement already satisfied: lxml in /usr/local/lib/python3.12/dist-packages (from dataframe-image<0.3.0,>=0.2.6->vuegen==0.5.1.post4.dev0+17ce3cc) (5.4.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from dataframe-image<0.3.0,>=0.2.6->vuegen==0.5.1.post4.dev0+17ce3cc) (4.13.5)
# Collecting cssutils (from dataframe-image<0.3.0,>=0.2.6->vuegen==0.5.1.post4.dev0+17ce3cc)
#   Downloading cssutils-2.11.1-py3-none-any.whl.metadata (8.7 kB)
# Collecting playwright (from dataframe-image<0.3.0,>=0.2.6->vuegen==0.5.1.post4.dev0+17ce3cc)
#   Downloading playwright-1.56.0-py3-none-manylinux1_x86_64.whl.metadata (3.5 kB)
# Collecting cssselect (from dataframe-image<0.3.0,>=0.2.6->vuegen==0.5.1.post4.dev0+17ce3cc)
#   Downloading cssselect-1.3.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: ipython in /usr/local/lib/python3.12/dist-packages (from itables<3.0.0,>=2.2.2->vuegen==0.5.1.post4.dev0+17ce3cc) (7.34.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4.0.0,>=3.9.2->vuegen==0.5.1.post4.dev0+17ce3cc) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4.0.0,>=3.9.2->vuegen==0.5.1.post4.dev0+17ce3cc) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4.0.0,>=3.9.2->vuegen==0.5.1.post4.dev0+17ce3cc) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4.0.0,>=3.9.2->vuegen==0.5.1.post4.dev0+17ce3cc) (1.4.9)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4.0.0,>=3.9.2->vuegen==0.5.1.post4.dev0+17ce3cc) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4.0.0,>=3.9.2->vuegen==0.5.1.post4.dev0+17ce3cc) (2.9.0.post0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.12/dist-packages (from nbclient<0.11.0,>=0.10.0->vuegen==0.5.1.post4.dev0+17ce3cc) (7.4.9)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /usr/local/lib/python3.12/dist-packages (from nbclient<0.11.0,>=0.10.0->vuegen==0.5.1.post4.dev0+17ce3cc) (5.9.1)
# Requirement already satisfied: traitlets>=5.4 in /usr/local/lib/python3.12/dist-packages (from nbclient<0.11.0,>=0.10.0->vuegen==0.5.1.post4.dev0+17ce3cc) (5.7.1)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.12/dist-packages (from nbformat<6.0.0,>=5.10.4->vuegen==0.5.1.post4.dev0+17ce3cc) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.12/dist-packages (from nbformat<6.0.0,>=5.10.4->vuegen==0.5.1.post4.dev0+17ce3cc) (4.25.1)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.12/dist-packages (from openpyxl<4.0.0,>=3.1.5->vuegen==0.5.1.post4.dev0+17ce3cc) (2.0.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5.0->scikit-bio) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5.0->scikit-bio) (2025.2)
# Requirement already satisfied: pyarrow>=10.0.1 in /usr/local/lib/python3.12/dist-packages (from pandas[parquet]<3.0.0,>=2.2.2->vuegen==0.5.1.post4.dev0+17ce3cc) (18.1.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from plotly<6.0.0,>=5.15.0->vuegen==0.5.1.post4.dev0+17ce3cc) (8.5.0)
# Requirement already satisfied: jinja2>=2.9.6 in /usr/local/lib/python3.12/dist-packages (from pyvis<0.4.0,>=0.3.2->vuegen==0.5.1.post4.dev0+17ce3cc) (3.1.6)
# Requirement already satisfied: jsonpickle>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from pyvis<0.4.0,>=0.3.2->vuegen==0.5.1.post4.dev0+17ce3cc) (4.1.1)
# Requirement already satisfied: networkx>=1.11 in /usr/local/lib/python3.12/dist-packages (from pyvis<0.4.0,>=0.3.2->vuegen==0.5.1.post4.dev0+17ce3cc) (3.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.20.0->scikit-bio) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.20.0->scikit-bio) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.20.0->scikit-bio) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.20.0->scikit-bio) (2025.10.5)
# Requirement already satisfied: blinker<2,>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from streamlit<2.0.0,>=1.39.0->vuegen==0.5.1.post4.dev0+17ce3cc) (1.9.0)
# Requirement already satisfied: cachetools<7,>=4.0 in /usr/local/lib/python3.12/dist-packages (from streamlit<2.0.0,>=1.39.0->vuegen==0.5.1.post4.dev0+17ce3cc) (5.5.2)
# Requirement already satisfied: protobuf<7,>=3.20 in /usr/local/lib/python3.12/dist-packages (from streamlit<2.0.0,>=1.39.0->vuegen==0.5.1.post4.dev0+17ce3cc) (5.29.5)
# Requirement already satisfied: toml<2,>=0.10.1 in /usr/local/lib/python3.12/dist-packages (from streamlit<2.0.0,>=1.39.0->vuegen==0.5.1.post4.dev0+17ce3cc) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in /usr/local/lib/python3.12/dist-packages (from streamlit<2.0.0,>=1.39.0->vuegen==0.5.1.post4.dev0+17ce3cc) (4.15.0)
# Requirement already satisfied: watchdog<7,>=2.1.5 in /usr/local/lib/python3.12/dist-packages (from streamlit<2.0.0,>=1.39.0->vuegen==0.5.1.post4.dev0+17ce3cc) (6.0.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /usr/local/lib/python3.12/dist-packages (from streamlit<2.0.0,>=1.39.0->vuegen==0.5.1.post4.dev0+17ce3cc) (3.1.45)
# Collecting pydeck<1,>=0.8.0b4 (from streamlit<2.0.0,>=1.39.0->vuegen==0.5.1.post4.dev0+17ce3cc)
#   Downloading pydeck-0.9.1-py2.py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in /usr/local/lib/python3.12/dist-packages (from streamlit<2.0.0,>=1.39.0->vuegen==0.5.1.post4.dev0+17ce3cc) (6.5.1)
# Requirement already satisfied: narwhals>=1.14.2 in /usr/local/lib/python3.12/dist-packages (from altair[save]->vuegen==0.5.1.post4.dev0+17ce3cc) (2.11.0)
# Collecting jupyter (from quarto-cli->vuegen==0.5.1.post4.dev0+17ce3cc)
#   Downloading jupyter-1.1.1-py2.py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: wheel in /usr/local/lib/python3.12/dist-packages (from quarto-cli->vuegen==0.5.1.post4.dev0+17ce3cc) (0.45.1)
# Collecting python-decouple (from streamlit-aggrid->vuegen==0.5.1.post4.dev0+17ce3cc)
#   Downloading python_decouple-3.8-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10.2->dataframe-image<0.3.0,>=0.2.6->vuegen==0.5.1.post4.dev0+17ce3cc) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10.2->dataframe-image<0.3.0,>=0.2.6->vuegen==0.5.1.post4.dev0+17ce3cc) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10.2->dataframe-image<0.3.0,>=0.2.6->vuegen==0.5.1.post4.dev0+17ce3cc) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10.2->dataframe-image<0.3.0,>=0.2.6->vuegen==0.5.1.post4.dev0+17ce3cc) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10.2->dataframe-image<0.3.0,>=0.2.6->vuegen==0.5.1.post4.dev0+17ce3cc) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10.2->dataframe-image<0.3.0,>=0.2.6->vuegen==0.5.1.post4.dev0+17ce3cc) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.10.2->dataframe-image<0.3.0,>=0.2.6->vuegen==0.5.1.post4.dev0+17ce3cc) (1.22.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit<2.0.0,>=1.39.0->vuegen==0.5.1.post4.dev0+17ce3cc) (4.0.12)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.12/dist-packages (from ipython->itables<3.0.0,>=2.2.2->vuegen==0.5.1.post4.dev0+17ce3cc) (75.2.0)
# Collecting jedi>=0.16 (from ipython->itables<3.0.0,>=2.2.2->vuegen==0.5.1.post4.dev0+17ce3cc)
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.12/dist-packages (from ipython->itables<3.0.0,>=2.2.2->vuegen==0.5.1.post4.dev0+17ce3cc) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from ipython->itables<3.0.0,>=2.2.2->vuegen==0.5.1.post4.dev0+17ce3cc) (3.0.52)
# Requirement already satisfied: pygments in /usr/local/lib/python3.12/dist-packages (from ipython->itables<3.0.0,>=2.2.2->vuegen==0.5.1.post4.dev0+17ce3cc) (2.19.2)
# Requirement already satisfied: backcall in /usr/local/lib/python3.12/dist-packages (from ipython->itables<3.0.0,>=2.2.2->vuegen==0.5.1.post4.dev0+17ce3cc) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.12/dist-packages (from ipython->itables<3.0.0,>=2.2.2->vuegen==0.5.1.post4.dev0+17ce3cc) (0.2.1)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from ipython->itables<3.0.0,>=2.2.2->vuegen==0.5.1.post4.dev0+17ce3cc) (4.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2>=2.9.6->pyvis<0.4.0,>=0.3.2->vuegen==0.5.1.post4.dev0+17ce3cc) (3.0.3)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat<6.0.0,>=5.10.4->vuegen==0.5.1.post4.dev0+17ce3cc) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat<6.0.0,>=5.10.4->vuegen==0.5.1.post4.dev0+17ce3cc) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat<6.0.0,>=5.10.4->vuegen==0.5.1.post4.dev0+17ce3cc) (0.28.0)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.12/dist-packages (from jupyter-client>=6.1.12->nbclient<0.11.0,>=0.10.0->vuegen==0.5.1.post4.dev0+17ce3cc) (0.4)
# Requirement already satisfied: nest-asyncio>=1.5.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-client>=6.1.12->nbclient<0.11.0,>=0.10.0->vuegen==0.5.1.post4.dev0+17ce3cc) (1.6.0)
# Requirement already satisfied: pyzmq>=23.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-client>=6.1.12->nbclient<0.11.0,>=0.10.0->vuegen==0.5.1.post4.dev0+17ce3cc) (26.2.1)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.12/dist-packages (from jupyter-core!=5.0.*,>=4.12->nbclient<0.11.0,>=0.10.0->vuegen==0.5.1.post4.dev0+17ce3cc) (4.5.0)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.12/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->dataframe-image<0.3.0,>=0.2.6->vuegen==0.5.1.post4.dev0+17ce3cc) (6.3.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->dataframe-image<0.3.0,>=0.2.6->vuegen==0.5.1.post4.dev0+17ce3cc) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->dataframe-image<0.3.0,>=0.2.6->vuegen==0.5.1.post4.dev0+17ce3cc) (0.3.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->dataframe-image<0.3.0,>=0.2.6->vuegen==0.5.1.post4.dev0+17ce3cc) (1.5.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib<4.0.0,>=3.9.2->vuegen==0.5.1.post4.dev0+17ce3cc) (1.17.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->dataframe-image<0.3.0,>=0.2.6->vuegen==0.5.1.post4.dev0+17ce3cc) (2.8)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.12/dist-packages (from cssutils->dataframe-image<0.3.0,>=0.2.6->vuegen==0.5.1.post4.dev0+17ce3cc) (10.8.0)
# Requirement already satisfied: notebook in /usr/local/lib/python3.12/dist-packages (from jupyter->quarto-cli->vuegen==0.5.1.post4.dev0+17ce3cc) (6.5.7)
# Requirement already satisfied: jupyter-console in /usr/local/lib/python3.12/dist-packages (from jupyter->quarto-cli->vuegen==0.5.1.post4.dev0+17ce3cc) (6.6.3)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.12/dist-packages (from jupyter->quarto-cli->vuegen==0.5.1.post4.dev0+17ce3cc) (6.17.1)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.12/dist-packages (from jupyter->quarto-cli->vuegen==0.5.1.post4.dev0+17ce3cc) (7.7.1)
# Collecting jupyterlab (from jupyter->quarto-cli->vuegen==0.5.1.post4.dev0+17ce3cc)
#   Downloading jupyterlab-4.4.10-py3-none-any.whl.metadata (16 kB)
# Collecting pyee<14,>=13 (from playwright->dataframe-image<0.3.0,>=0.2.6->vuegen==0.5.1.post4.dev0+17ce3cc)
#   Downloading pyee-13.0.0-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: greenlet<4.0.0,>=3.1.1 in /usr/local/lib/python3.12/dist-packages (from playwright->dataframe-image<0.3.0,>=0.2.6->vuegen==0.5.1.post4.dev0+17ce3cc) (3.2.4)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.12/dist-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=5->dataframe-image<0.3.0,>=0.2.6->vuegen==0.5.1.post4.dev0+17ce3cc) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->dataframe-image<0.3.0,>=0.2.6->vuegen==0.5.1.post4.dev0+17ce3cc) (1.4.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit<2.0.0,>=1.39.0->vuegen==0.5.1.post4.dev0+17ce3cc) (5.0.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.16->ipython->itables<3.0.0,>=2.2.2->vuegen==0.5.1.post4.dev0+17ce3cc) (0.8.5)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.12/dist-packages (from pexpect>4.3->ipython->itables<3.0.0,>=2.2.2->vuegen==0.5.1.post4.dev0+17ce3cc) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->itables<3.0.0,>=2.2.2->vuegen==0.5.1.post4.dev0+17ce3cc) (0.2.14)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.12/dist-packages (from ipykernel->jupyter->quarto-cli->vuegen==0.5.1.post4.dev0+17ce3cc) (1.8.15)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from ipykernel->jupyter->quarto-cli->vuegen==0.5.1.post4.dev0+17ce3cc) (5.9.5)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->jupyter->quarto-cli->vuegen==0.5.1.post4.dev0+17ce3cc) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->jupyter->quarto-cli->vuegen==0.5.1.post4.dev0+17ce3cc) (3.6.10)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->jupyter->quarto-cli->vuegen==0.5.1.post4.dev0+17ce3cc) (3.0.16)
# Collecting async-lru>=1.0.0 (from jupyterlab->jupyter->quarto-cli->vuegen==0.5.1.post4.dev0+17ce3cc)
#   Downloading async_lru-2.0.5-py3-none-any.whl.metadata (4.5 kB)
# Requirement already satisfied: httpx<1,>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jupyterlab->jupyter->quarto-cli->vuegen==0.5.1.post4.dev0+17ce3cc) (0.28.1)
# Collecting jupyter-lsp>=2.0.0 (from jupyterlab->jupyter->quarto-cli->vuegen==0.5.1.post4.dev0+17ce3cc)
#   Downloading jupyter_lsp-2.3.0-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /usr/local/lib/python3.12/dist-packages (from jupyterlab->jupyter->quarto-cli->vuegen==0.5.1.post4.dev0+17ce3cc) (2.14.0)
# Collecting jupyterlab-server<3,>=2.27.1 (from jupyterlab->jupyter->quarto-cli->vuegen==0.5.1.post4.dev0+17ce3cc)
#   Downloading jupyterlab_server-2.28.0-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: notebook-shim>=0.2 in /usr/local/lib/python3.12/dist-packages (from jupyterlab->jupyter->quarto-cli->vuegen==0.5.1.post4.dev0+17ce3cc) (0.2.4)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.12/dist-packages (from notebook->jupyter->quarto-cli->vuegen==0.5.1.post4.dev0+17ce3cc) (25.1.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from notebook->jupyter->quarto-cli->vuegen==0.5.1.post4.dev0+17ce3cc) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.12/dist-packages (from notebook->jupyter->quarto-cli->vuegen==0.5.1.post4.dev0+17ce3cc) (0.18.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.12/dist-packages (from notebook->jupyter->quarto-cli->vuegen==0.5.1.post4.dev0+17ce3cc) (0.23.1)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.12/dist-packages (from notebook->jupyter->quarto-cli->vuegen==0.5.1.post4.dev0+17ce3cc) (1.3.3)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter->quarto-cli->vuegen==0.5.1.post4.dev0+17ce3cc) (4.11.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter->quarto-cli->vuegen==0.5.1.post4.dev0+17ce3cc) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab->jupyter->quarto-cli->vuegen==0.5.1.post4.dev0+17ce3cc) (0.16.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->quarto-cli->vuegen==0.5.1.post4.dev0+17ce3cc) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->quarto-cli->vuegen==0.5.1.post4.dev0+17ce3cc) (0.5.3)
# Requirement already satisfied: overrides>=5.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->quarto-cli->vuegen==0.5.1.post4.dev0+17ce3cc) (7.7.0)
# Requirement already satisfied: websocket-client>=1.7 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->quarto-cli->vuegen==0.5.1.post4.dev0+17ce3cc) (1.9.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.12/dist-packages (from argon2-cffi->notebook->jupyter->quarto-cli->vuegen==0.5.1.post4.dev0+17ce3cc) (25.1.0)
# Requirement already satisfied: babel>=2.10 in /usr/local/lib/python3.12/dist-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->quarto-cli->vuegen==0.5.1.post4.dev0+17ce3cc) (2.17.0)
# Collecting json5>=0.9.0 (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->quarto-cli->vuegen==0.5.1.post4.dev0+17ce3cc)
#   Downloading json5-0.12.1-py3-none-any.whl.metadata (36 kB)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.12/dist-packages (from anyio->httpx<1,>=0.25.0->jupyterlab->jupyter->quarto-cli->vuegen==0.5.1.post4.dev0+17ce3cc) (1.3.1)
# Requirement already satisfied: python-json-logger>=2.0.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->quarto-cli->vuegen==0.5.1.post4.dev0+17ce3cc) (4.0.0)
# Requirement already satisfied: rfc3339-validator in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->quarto-cli->vuegen==0.5.1.post4.dev0+17ce3cc) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->quarto-cli->vuegen==0.5.1.post4.dev0+17ce3cc) (0.1.1)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook->jupyter->quarto-cli->vuegen==0.5.1.post4.dev0+17ce3cc) (2.0.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook->jupyter->quarto-cli->vuegen==0.5.1.post4.dev0+17ce3cc) (2.23)
# Requirement already satisfied: fqdn in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->quarto-cli->vuegen==0.5.1.post4.dev0+17ce3cc) (1.5.1)
# Requirement already satisfied: isoduration in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->quarto-cli->vuegen==0.5.1.post4.dev0+17ce3cc) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->quarto-cli->vuegen==0.5.1.post4.dev0+17ce3cc) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->quarto-cli->vuegen==0.5.1.post4.dev0+17ce3cc) (1.1.0)
# Requirement already satisfied: uri-template in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->quarto-cli->vuegen==0.5.1.post4.dev0+17ce3cc) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->quarto-cli->vuegen==0.5.1.post4.dev0+17ce3cc) (25.10.0)
# Requirement already satisfied: lark>=1.2.2 in /usr/local/lib/python3.12/dist-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->quarto-cli->vuegen==0.5.1.post4.dev0+17ce3cc) (1.3.1)
# Requirement already satisfied: arrow>=0.15.0 in /usr/local/lib/python3.12/dist-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->quarto-cli->vuegen==0.5.1.post4.dev0+17ce3cc) (1.4.0)
# Downloading scikit_bio-0.7.1.post1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (10.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 92.6 MB/s eta 0:00:00
# Downloading array_api_compat-1.12.0-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.2/58.2 kB 4.3 MB/s eta 0:00:00
# Downloading biom_format-2.1.17-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 90.8 MB/s eta 0:00:00
# Downloading dataframe_image-0.2.7-py3-none-any.whl (6.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.7/6.7 MB 90.6 MB/s eta 0:00:00
# Downloading itables-2.5.2-py3-none-any.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 90.0 MB/s eta 0:00:00
# Downloading kaleido-0.2.1-py2.py3-none-manylinux1_x86_64.whl (79.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 9.4 MB/s eta 0:00:00
# Downloading pyvis-0.3.2-py3-none-any.whl (756 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 756.0/756.0 kB 44.0 MB/s eta 0:00:00
# Downloading streamlit-1.51.0-py3-none-any.whl (10.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 112.1 MB/s eta 0:00:00
# Downloading vl_convert_python-1.8.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (33.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.0/33.0 MB 51.5 MB/s eta 0:00:00
# Downloading streamlit_aggrid-1.2.0.post1-py3-none-any.whl (5.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.7/5.7 MB 116.2 MB/s eta 0:00:00
# Downloading pydeck-0.9.1-py2.py3-none-any.whl (6.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 106.5 MB/s eta 0:00:00
# Downloading cssselect-1.3.0-py3-none-any.whl (18 kB)
# Downloading cssutils-2.11.1-py3-none-any.whl (385 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 385.7/385.7 kB 20.2 MB/s eta 0:00:00
# Downloading jupyter-1.1.1-py2.py3-none-any.whl (2.7 kB)
# Downloading playwright-1.56.0-py3-none-manylinux1_x86_64.whl (46.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.3/46.3 MB 12.3 MB/s eta 0:00:00
# Downloading python_decouple-3.8-py3-none-any.whl (9.9 kB)
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 68.3 MB/s eta 0:00:00
# Downloading pyee-13.0.0-py3-none-any.whl (15 kB)
# Downloading jupyterlab-4.4.10-py3-none-any.whl (12.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 104.5 MB/s eta 0:00:00
# Downloading async_lru-2.0.5-py3-none-any.whl (6.1 kB)
# Downloading jupyter_lsp-2.3.0-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.7/76.7 kB 6.5 MB/s eta 0:00:00
# Downloading jupyterlab_server-2.28.0-py3-none-any.whl (59 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.8/59.8 kB 4.8 MB/s eta 0:00:00
# Downloading json5-0.12.1-py3-none-any.whl (36 kB)
# Building wheels for collected packages: vuegen, quarto-cli
#   Building wheel for vuegen (pyproject.toml) ... done
#   Created wheel for vuegen: filename=vuegen-0.5.1.post4.dev0+17ce3cc-py3-none-any.whl size=57145 sha256=eae09ca53ebbd7590815bde31c02bbe9514c7504c5aec09d8d12bfbc7e962328
#   Stored in directory: /tmp/pip-ephem-wheel-cache-re8__x46/wheels/7b/7f/e7/7347bed7a9a0f5d2f25617e2d5c189a09b987ca33782fc2f37
#   Building wheel for quarto-cli (pyproject.toml) ... done
#   Created wheel for quarto-cli: filename=quarto_cli-1.8.26-py3-none-any.whl size=126466836 sha256=a2673e2c3a3a3db050ab0ef66caeded630adcccdf89720accbfb8510baba18d9
#   Stored in directory: /root/.cache/pip/wheels/15/15/65/da86625bc377710a7197156a04ac764eed8d01782252d0d4dd
# Successfully built vuegen quarto-cli
# Installing collected packages: python-decouple, kaleido, vl-convert-python, pyee, json5, jedi, cssutils, cssselect, async-lru, array-api-compat, pydeck, playwright, pyvis, itables, biom-format, scikit-bio, streamlit, streamlit-aggrid, dataframe-image, jupyterlab-server, jupyter-lsp, jupyterlab, jupyter, quarto-cli, vuegen
# Successfully installed array-api-compat-1.12.0 async-lru-2.0.5 biom-format-2.1.17 cssselect-1.3.0 cssutils-2.11.1 dataframe-image-0.2.7 itables-2.5.2 jedi-0.19.2 json5-0.12.1 jupyter-1.1.1 jupyter-lsp-2.3.0 jupyterlab-4.4.10 jupyterlab-server-2.28.0 kaleido-0.2.1 playwright-1.56.0 pydeck-0.9.1 pyee-13.0.0 python-decouple-3.8 pyvis-0.3.2 quarto-cli-1.8.26 scikit-bio-0.7.1.post1 streamlit-1.51.0 streamlit-aggrid-1.2.0.post1 vl-convert-python-1.8.0 vuegen-0.5.1.post4.dev0+17ce3cc

# %% [markdown]
# ## Data Setup: Directory Creation and Downloads
#
# These cells set up the working environment by creating necessary directories and downloading the raw data files from the HMP2 public repository.
#
# 1.  **Directory Creation:** Creates `metagenomics/data` and `metagenomics/results` folders to organize input and output files.
# 2.  **Data Download:**
#       * Downloads a gzipped file containing the **taxonomic profiles** (`taxonomic_profiles.tsv.gz`), which is an abundance table where rows are microbial taxa and columns are samples. This file is then unzipped.
#       * Downloads the **sample metadata** (`hmp2_metadata_2018-08-20.csv`), which contains information about each sample, including the participant's diagnosis.

# %%
! mkdir metagenomics
! mkdir metagenomics/data
! mkdir metagenomics/results
! mkdir metagenomics/results/Relative_abundance/
! mkdir metagenomics/results/Alpha_diversity/
! mkdir metagenomics/results/Differential_abundance/
! mkdir metagenomics/results/Principal_component_analysis/
! mkdir metagenomics/results/PCoA/
! mkdir metagenomics/results/PERMANOVA/

# %%
! wget https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/products/HMP2/MGX/2018-05-04/taxonomic_profiles.tsv.gz -O metagenomics/data/taxonomic_profiles.tsv.gz
! gunzip metagenomics/data/taxonomic_profiles.tsv.gz
# Out:
# --2025-11-13 11:52:50--  https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/products/HMP2/MGX/2018-05-04/taxonomic_profiles.tsv.gz
# Resolving g-227ca.190ebd.75bc.data.globus.org (g-227ca.190ebd.75bc.data.globus.org)... 140.247.111.40, 140.247.111.39
# Connecting to g-227ca.190ebd.75bc.data.globus.org (g-227ca.190ebd.75bc.data.globus.org)|140.247.111.40|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/x-gzip]
# Saving to: ‘metagenomics/data/taxonomic_profiles.tsv.gz’
#
# metagenomics/data/t     [ <=>                ] 651.01K  4.05MB/s    in 0.2s
#
# 2025-11-13 11:52:51 (4.05 MB/s) - ‘metagenomics/data/taxonomic_profiles.tsv.gz’ saved [666634]

# %%
! wget https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/metadata/hmp2_metadata_2018-08-20.csv -O metagenomics/data/hmp2_metadata_2018-08-20.csv
# Out:
# --2025-11-13 11:52:51--  https://g-227ca.190ebd.75bc.data.globus.org/ibdmdb/metadata/hmp2_metadata_2018-08-20.csv
# Resolving g-227ca.190ebd.75bc.data.globus.org (g-227ca.190ebd.75bc.data.globus.org)... 140.247.111.40, 140.247.111.39
# Connecting to g-227ca.190ebd.75bc.data.globus.org (g-227ca.190ebd.75bc.data.globus.org)|140.247.111.40|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/csv]
# Saving to: ‘metagenomics/data/hmp2_metadata_2018-08-20.csv’
#
# metagenomics/data/h     [  <=>               ]   8.65M  26.9MB/s    in 0.3s
#
# 2025-11-13 11:52:52 (26.9 MB/s) - ‘metagenomics/data/hmp2_metadata_2018-08-20.csv’ saved [9074342]

# %% [markdown]
# ## Data Loading, Inspection, and Filtering
#
# The raw data is loaded into `pandas` DataFrames, the sample IDs are set as the index, and an initial filtering step is performed to prepare the data for analysis.
#
# **Loading Data:** The taxonomic profile table (`data`) and the metadata table (`metadata`) are loaded and indexed by their respective IDs.

# %%
import pandas as pd

data = pd.read_csv('metagenomics/data/taxonomic_profiles.tsv', sep='\t')
data = data.loc[:,~data.columns.duplicated()]
data = data.set_index('#SampleID')
print(data.head())

metadata = pd.read_csv('metagenomics/data/hmp2_metadata_2018-08-20.csv')
print(metadata.shape)
metadata = metadata.drop_duplicates(subset='External ID', keep='first')
print(metadata.shape)
metadata = metadata.set_index('External ID')
print(metadata.head())
# Out:
#                                                     CSM5FZ4M  CSM5MCUO  \
# #SampleID
# k__Archaea                                               0.0       0.0
# k__Archaea|p__Euryarchaeota                              0.0       0.0
# k__Archaea|p__Euryarchaeota|c__Methanobacteria           0.0       0.0
# k__Archaea|p__Euryarchaeota|c__Methanobacteria|...       0.0       0.0
# k__Archaea|p__Euryarchaeota|c__Methanobacteria|...       0.0       0.0
#
#                                                     CSM5MCVL  CSM5MCVN  \
# #SampleID
# k__Archaea                                               0.0       0.0
# k__Archaea|p__Euryarchaeota                              0.0       0.0
# k__Archaea|p__Euryarchaeota|c__Methanobacteria           0.0       0.0
# k__Archaea|p__Euryarchaeota|c__Methanobacteria|...       0.0       0.0
# k__Archaea|p__Euryarchaeota|c__Methanobacteria|...       0.0       0.0
#
#                                                     CSM5MCW6  CSM5MCWC  \
# #SampleID
# k__Archaea                                               0.0       0.0
# k__Archaea|p__Euryarchaeota                              0.0       0.0
# k__Archaea|p__Euryarchaeota|c__Methanobacteria           0.0       0.0
# k__Archaea|p__Euryarchaeota|c__Methanobacteria|...       0.0       0.0
# k__Archaea|p__Euryarchaeota|c__Methanobacteria|...       0.0       0.0
#
#                                                     CSM5MCWE  CSM5MCWG  \
# #SampleID
# k__Archaea                                               0.0       0.0
# k__Archaea|p__Euryarchaeota                              0.0       0.0
# k__Archaea|p__Euryarchaeota|c__Methanobacteria           0.0       0.0
# k__Archaea|p__Euryarchaeota|c__Methanobacteria|...       0.0       0.0
# k__Archaea|p__Euryarchaeota|c__Methanobacteria|...       0.0       0.0
#
#                                                     CSM5MCWQ  CSM5MCX3  ...  \
# #SampleID                                                               ...
# k__Archaea                                               0.0       0.0  ...
# k__Archaea|p__Euryarchaeota                              0.0       0.0  ...
# k__Archaea|p__Euryarchaeota|c__Methanobacteria           0.0       0.0  ...
# k__Archaea|p__Euryarchaeota|c__Methanobacteria|...       0.0       0.0  ...
# k__Archaea|p__Euryarchaeota|c__Methanobacteria|...       0.0       0.0  ...
#
#                                                     CSM5MCVJ_P  CSM5MCWI_P  \
# #SampleID
# k__Archaea                                                 0.0         0.0
# k__Archaea|p__Euryarchaeota                                0.0         0.0
# k__Archaea|p__Euryarchaeota|c__Methanobacteria             0.0         0.0
# k__Archaea|p__Euryarchaeota|c__Methanobacteria|...         0.0         0.0
# k__Archaea|p__Euryarchaeota|c__Methanobacteria|...         0.0         0.0
#
#                                                     MSM5LLHA_P  HSM5MD59_P  \
# #SampleID
# k__Archaea                                                 0.0         0.0
# k__Archaea|p__Euryarchaeota                                0.0         0.0
# k__Archaea|p__Euryarchaeota|c__Methanobacteria             0.0         0.0
# k__Archaea|p__Euryarchaeota|c__Methanobacteria|...         0.0         0.0
# k__Archaea|p__Euryarchaeota|c__Methanobacteria|...         0.0         0.0
#
#                                                     HSM5MD8N_P  CSM6J2H9_P  \
# #SampleID
# k__Archaea                                                 0.0         0.0
# k__Archaea|p__Euryarchaeota                                0.0         0.0
# k__Archaea|p__Euryarchaeota|c__Methanobacteria             0.0         0.0
# k__Archaea|p__Euryarchaeota|c__Methanobacteria|...         0.0         0.0
# k__Archaea|p__Euryarchaeota|c__Methanobacteria|...         0.0         0.0
#
#                                                     HSM5MD4A_P  CSM5MCUW_P  \
# #SampleID
# k__Archaea                                                 0.0    0.000093
# k__Archaea|p__Euryarchaeota                                0.0    0.000093
# k__Archaea|p__Euryarchaeota|c__Methanobacteria             0.0    0.000093
# k__Archaea|p__Euryarchaeota|c__Methanobacteria|...         0.0    0.000093
# k__Archaea|p__Euryarchaeota|c__Methanobacteria|...         0.0    0.000093
#
#                                                     ESM5MEBA_P  HSM5FZC2_P
# #SampleID
# k__Archaea                                                 0.0         0.0
# k__Archaea|p__Euryarchaeota                                0.0         0.0
# k__Archaea|p__Euryarchaeota|c__Methanobacteria             0.0         0.0
# k__Archaea|p__Euryarchaeota|c__Methanobacteria|...         0.0         0.0
# k__Archaea|p__Euryarchaeota|c__Methanobacteria|...         0.0         0.0
#
# [5 rows x 1638 columns]
# /tmp/ipython-input-4118772372.py:8: DtypeWarning: Columns (12,13,14,40,46,55,65,66,67,68,177,294,298,299,300,301,304,305,306,307,308,309,310,318,320,328,330,346,348,350,352,354,359,361,363,366,373,377,381,383,418,419,432,433,434,435,436,438,439,440,441,442,444,445,446,447,448,450,451,452,453,454) have mixed types. Specify dtype option on import or set low_memory=False.
#   metadata = pd.read_csv('metagenomics/data/hmp2_metadata_2018-08-20.csv')
# (5533, 490)
# (2892, 490)
#                   Project Participant ID site_sub_coll   data_type  week_num  \
# External ID
# 206615       C3001CSC1_BP          C3001     C3001CSC1  biopsy_16S       2.0
# 206614       C3001CSC2_BP          C3001     C3001CSC2  biopsy_16S       2.0
# 206617       C3002CSC1_BP          C3002     C3002CSC1  biopsy_16S       0.0
# 206619       C3002CSC2_BP          C3002     C3002CSC2  biopsy_16S       0.0
# 206616       C3002CSC3_BP          C3002     C3002CSC3  biopsy_16S       0.0
#
#             date_of_receipt  interval_days  visit_num Research Project  \
# External ID
# 206615                  NaN            NaN          1           ibdmdb
# 206614                  NaN            NaN          1           ibdmdb
# 206617                  NaN            NaN          1           ibdmdb
# 206619                  NaN            NaN          1           ibdmdb
# 206616                  NaN            NaN          1           ibdmdb
#
#             PDO Number  ...  FecalCal received at MGH:  \
# External ID             ...
# 206615             NaN  ...                         No
# 206614             NaN  ...                         No
# 206617             NaN  ...                         No
# 206619             NaN  ...                         No
# 206616             NaN  ...                         No
#
#             Proteomics received at LBNL: Stool Sample ID:  Tube A  (EtOH)  \
# External ID
# 206615                                No                              NaN
# 206614                                No                              NaN
# 206617                                No                              NaN
# 206619                                No                              NaN
# 206616                                No                              NaN
#
#             Sample ID: Tube B (No preservative)  \
# External ID
# 206615                                      NaN
# 206614                                      NaN
# 206617                                      NaN
# 206619                                      NaN
# 206616                                      NaN
#
#              Tube A and B received at Broad:  stool_id  smoking status  \
# External ID
# 206615                                    No       NaN             NaN
# 206614                                    No       NaN             NaN
# 206617                                    No       NaN             NaN
# 206619                                    No       NaN             NaN
# 206616                                    No       NaN             NaN
#
#              Number years smoked  Age when started smoking  \
# External ID
# 206615                       NaN                       NaN
# 206614                       NaN                       NaN
# 206617                       NaN                       NaN
# 206619                       NaN                       NaN
# 206616                       NaN                       NaN
#
#              How many cigarettes/cigars/etc. do you smoke per day?
# External ID
# 206615                                                     NaN
# 206614                                                     NaN
# 206617                                                     NaN
# 206619                                                     NaN
# 206616                                                     NaN
#
# [5 rows x 489 columns]

# %% [markdown]
# **Note:** There is a lot of metadata available for these samples.

# %%
metadata.columns.tolist()
# Out:
# ['Project',
#  'Participant ID',
#  'site_sub_coll',
#  'data_type',
#  'week_num',
#  'date_of_receipt',
#  'interval_days',
#  'visit_num',
#  'Research Project',
#  'PDO Number',
#  'GSSR IDs',
#  'Product',
#  'LCSET',
#  'Aggregated Lanes',
#  'WR ID',
#  '# Lanes in Aggregation',
#  'reads_raw',
#  'reads_filtered',
#  'reads_qc_fail',
#  'reads_human',
#  'reads_ribosomal',
#  'reads_viral',
#  'Delta',
#  'IntervalName',
#  'IntervalSequence',
#  'ProjectSpecificID',
#  'site_name',
#  'Age at diagnosis',
#  'Has the subject had a cholecystectomy?',
#  'Has the subject had a prior abdominal surgery (other)?',
#  'Has the next visit been scheduled?',
#  'Has the subject been given new stool kits?',
#  'Has the subject completed the FFQ/YAQ?',
#  'Education Level',
#  'Occupation',
#  'Scanned FFQ/YAQ document:',
#  'FFQ/YAQ results:',
#  'Has the subject had an appendectomy?',
#  'Has the subject had a tonsillectomy?',
#  'biopsy_location',
#  'Were study bloods drawn?',
#  'Whole blood received at Broad:',
#  'Serum tube #1 received at CSMC:',
#  'Serum tubes #2-4 received at MGH:',
#  'Whole Blood (DNA)',
#  'Serum #1',
#  'Serum #2',
#  'Serum #3',
#  'Serum #4',
#  'Number of flora tubes collected:',
#  'Rectum Flora:',
#  'Ileum flora:',
#  'Other inflamed flora:',
#  'Non-inflamed flora:',
#  'Have samples been sent for histopathology?',
#  'Number of tubes collected for epithelial cell biopsies:',
#  'Rectum cell biopsy:',
#  'Ileum cell biopsy:',
#  'Other inflamed cell biopsy:',
#  'Other non-inflamed cell biopsy:',
#  'FLora received at MGH:',
#  'RNA/DNA received at Broad:',
#  'ECP received at Washington U:',
#  'Number of DNA/RNA tubes collected:',
#  'Rectum DNA/RNA:',
#  'Ileum DNA/RNA:',
#  'Other Inflamed DNA/RNA:',
#  'Non-inflamed DNA/RNA:',
#  'consent_age',
#  'diagnosis',
#  'Soft drinks, tea or coffee with sugar (corn syrup, maple syrup, cane sugar, etc)',
#  'Diet soft drinks, tea or coffee with sugar (Stevia, Equal, Splenda etc)',
#  'Fruit juice (orange, apple, cranberry, prune etc.)',
#  'Water',
#  'Alcohol (beer, brandy, spirits, hard liquor, wine, aperitif, etc.)',
#  'Yogurt or other foods containing active bacterial cultures (kefir, sauerkraut)',
#  'Dairy (milk, cream, ice cream, cheese, cream cheese)',
#  'Probiotic',
#  'Fruits (no juice) (Apples, raisins, bananas, oranges, strawberries, blueberries',
#  'Vegetables (salad, tomatoes, onions, greens, carrots, peppers, green beans, etc)',
#  '1) In the past 2 weeks, have you received any of the following medications',
#  'Beans (tofu, soy, soy burgers, lentils, Mexican beans, lima beans etc)',
#  'Whole grains (wheat, oats, brown rice, rye, quinoa, wheat bread, wheat pasta)',
#  'Starch (white rice, bread, pizza, potatoes, yams, cereals, pancakes, etc.)',
#  'Eggs',
#  'Processed meat (other red or white meat such as lunch meat, ham, salami, bologna',
#  'Red meat (beef, hamburger, pork, lamb)',
#  'White meat (chicken, turkey, etc.)',
#  'Shellfish (shrimp, lobster, scallops, etc.)',
#  'Fish (fish nuggets, breaded fish, fish cakes, salmon, tuna, etc.)',
#  'Sweets (pies, jam, chocolate, cake, cookies, etc.)',
#  'Antibiotics',
#  'Chemotherapy',
#  'Immunosuppressants (e.g. oral corticosteroids)',
#  '2) In the past 2 weeks, have you undergone a colonoscopy or other procedure',
#  '3) In the past 2 weeks, have you used an oral contrast',
#  '4) In the past 2 weeks, have you had diarrhea?',
#  '5) In the past 2 weeks, have you been hospitalized?',
#  '6) Have you ever had bowel surgery?',
#  'Tea or coffee no sugar and no sugar replacement',
#  'Did you grow up on a farm?',
#  'Did you attend daycare as a child?',
#  'Were you exposed to cigarette smoke as a child?',
#  'Were you born prematurely (more than 3 weeks early)?',
#  'Do you currently smoke marijuana?',
#  'If yes, how many times per month do you smoke marijuana on average?',
#  'In the past 2 months, have you used any acid reducing medication',
#  'If yes, how frequently do you take them?',
#  'In the past 2 months, have you used any medications modifying bile production',
#  'Do you use non-steroidal anti-inflammatory medications',
#  'Were you born in a hospital?',
#  'If yes, how frequently do you take them?.1',
#  'If you are female, do you use hormonal contraception?',
#  'If yes, what type of contraception?',
#  'Please list your current hormonal contraceptive:',
#  'If yes, for how many months have you been taking hormonal contraception?',
#  'Have you changed your hormonal contraceptive regimen in the past two months?',
#  'In the past 6 months, have you used antibiotics?',
#  'In the past 3 months, have you consumed any probiotics (other than yogurt)',
#  'In the past 3 months, how often have you consumed yogurt or other foods containi',
#  'Were you born via C-section?',
#  'What are your dietary preferences with respect to meat?',
#  'How often do you consume alcoholic beverages?',
#  'In the past 7 days, my sleep quality was...',
#  'In the past 7 days, my sleep was refreshing...',
#  'I had a problem with my sleep...',
#  'I had difficulty falling asleep...',
#  'My sleep was restless...',
#  'I tried hard to get to sleep...',
#  'I worried about not being able to fall asleep...',
#  'I was satisfied with my sleep...',
#  'Were you born in the United States?',
#  'In the past 7 days, I felt worthless...',
#  'I felt helpless...',
#  'I felt depressed...',
#  'I felt hopeless...',
#  'I felt like a failure...',
#  'I felt unhappy...',
#  'I felt that I had nothing to look forward to...',
#  'I felt that nothing could cheer me up...',
#  'In the past 7 days, I felt fearful...',
#  'I found it hard to focus on anything other than my anxiety...',
#  'If no, where were you born?',
#  'If no, in what year did you come to the United States?',
#  'Were you breastfed as an infant?',
#  'My worries overwhelmed me...',
#  'I felt uneasy...',
#  'I felt nervous...',
#  'I felt like I needed help for my anxiety...',
#  'I felt anxious...',
#  'I felt tense...',
#  'When was the last time you saw a dentist (generalist, prosthodontist, periodonti',
#  'When was the last time you had a dental cleaning? Choose the most recent option.',
#  'Manual toothbrush',
#  'Electric toothbrush',
#  'Alcohol-based mouthwash',
#  'Non alcoholic mouthwash',
#  'Floss',
#  'Water-based pick/jet',
#  'Tongue cleaner',
#  'Tooth-whiteners',
#  'Were you treated with antibiotics before the age of one?',
#  'Were you hospitalized before the age of five?',
#  'Did you have pets growing up?',
#  'Subject is unwilling or unable to provide biopsy, blood, and stool samples:',
#  'Subject has an immune mediated disease (i.e. rheumatoid arthritis, lupus, T1DM):',
#  'Subject is pregnant:',
#  'Subject has a known bleeding disorder:',
#  'Subject has an acute gastrointestinal infection:',
#  'Subject is actively being treated for a malignancy with chemotherapy:',
#  'Subject has been diagnosed with indeterminate colitis:',
#  'Subject has a stoma or pouch:',
#  'Subject has an acute gastrointestinal illness:',
#  'Subject has an acute gastrointestinal infection or IBD:',
#  'Behavior (B)',
#  'For UC and CD, has the disease classification changed since baseline?',
#  'Extent (E)',
#  'For months 3, 6, and 9 ONLY: Has the subject been given 6 new stool collection k',
#  'Location (L) prior to first surgery',
#  'Has the subject experienced a flare since the last study visit?',
#  'If yes, how many times?',
#  'Weight',
#  'Has the subject had a colonoscopy since the last visit?',
#  'Has the subject been hospitalized for any reason since the last study visit?',
#  'Has the subject had any accute diarrheal illnesses since the last study visit?',
#  'Has the subject used any antibiotics since the last visit?',
#  'fecalcal_ng_ml',
#  'Parents',
#  'Mother',
#  'Father',
#  'Siblings',
#  'Male sibling 1',
#  'Male sibling 2',
#  'Male sibling 3',
#  'Female sibling 1',
#  'Female sibling 2',
#  'Female sibling 3',
#  'Children',
#  'Male child 1',
#  'Male child 2',
#  'Male child 3',
#  'Female child 1',
#  'Female child 2',
#  'Female child 3',
#  'Grandparents',
#  'Male grandparent 1',
#  'Male grandparent 2',
#  'Female grandparent 1',
#  'Female grandparent 2',
#  'Distant Relative',
#  'Male distant relative 1',
#  'Male distant relative 2',
#  'Male distant relative 3',
#  'Female distant relative 1',
#  'Female distant relative 2',
#  'Female distant relative 3',
#  'Uveitis',
#  'Erythema nodosum',
#  'Aphthous ulcers',
#  'Pyoderma gangrenosum',
#  'Anal fissure',
#  'New fistula',
#  'Abscess',
#  'Was HBI completed?',
#  'General wellbeing',
#  'Abdominal pain',
#  'Number of liquid or very soft stools in the past 24 hours:',
#  'Abdominal mass',
#  'Arthralgia',
#  'hbi',
#  'Hispanic or Latino Origin',
#  'BMI',
#  'Height',
#  'Weight.1',
#  'Cancer - breast',
#  'Cancer - cholangiocarcinoma',
#  'Cancer - colon or rectum',
#  "Cancer - Hodgkin's lymphoma",
#  'Cancer - liver',
#  'Cancer - lung',
#  'Cancer - lymphoma (not otherwise specified)',
#  "Cancer - Non-Hodkin's lymphoma",
#  'Cancer - ovarian',
#  'Cancer - prostate',
#  'Other immune mediated diseases',
#  'Celiac sprue',
#  'Chronic bronchitis',
#  'Dermatitis herpetiformis',
#  'Familial Mediterranean fever',
#  "Grave's disease",
#  'Guillian-Barre Syndrome',
#  "Hashimoto's (autoimmune) thyroiditis",
#  'Idiopathic pulmonary fibrosis',
#  'Idiopathic thrombocytopenia purpura',
#  'Irritable bowel syndrome',
#  'Alopecia areata',
#  'Multiple sclerosis',
#  'Myasthenia gravis',
#  'Myocarditis',
#  'Neuropathy',
#  'Pericarditis',
#  'Pemphigus vulgaris',
#  'Pernicious anemia',
#  'Polymyositis or dermatomyositis',
#  'Primary biliary cirrhosis',
#  'Primary sclerosing cholangitis',
#  'Ankylosing spondylitis',
#  'Psoriasis',
#  'Rheumatoid arthritis',
#  'Sarcoidosis',
#  'Scleroderma (systemic sclerosis)',
#  "Sjogren's syndrome",
#  'Systemic lupus erythematosis',
#  'Temporal arteritis',
#  'Thyroid disease (uncertain diagnosis, not cancer)',
#  'Type I Diabetes (Juvenile Diabetes)',
#  'Vitiligo',
#  'Arthritis (uncertain diagnosis)',
#  "Wegener's granulomatosis",
#  'Asthma',
#  'Autoimmune hemolytic anemia',
#  'Autoimmune hepatitis',
#  "Bechet's syndrome",
#  'Did the patient sign informed consent?',
#  'Did the subject withdraw from the study?',
#  'Was subject terminated by investigator?',
#  'Reason for withdrawal or termination:',
#  'Subject is 18 years of age or older:',
#  'Subject is 17 years of age or younger:',
#  'Subject has a confirmed diagnosis of IBD:',
#  'Subject was diagnosed within the last 6 months:',
#  'Subject is NOT on an anti-TNF inhibitor:',
#  'Subject has had IBD for 5 years or more:',
#  'is_inflamed',
#  'Have the following labs been drawn within +/- 2 weeks?',
#  'CRP (mg/L)',
#  'ESR (mm/hr)',
#  'Location',
#  'What is the endoscopic grading of severity?',
#  'Location.1',
#  'What is the endoscopic grading of severity?.1',
#  "Modified Baron's Score",
#  'Partial Endoscopy',
#  "Was the Modified Baron's Score completed?",
#  'Location.2',
#  'What is the endoscopic grading of severity?.2',
#  'Location.3',
#  'What is the endoscopic grading of severity?.3',
#  'Location.4',
#  'What is the endoscopic grading of severity?.4',
#  'Has classification been verified by a physician?',
#  'Age at diagnosis (A)',
#  'baseline_montreal_location',
#  'Behavior (B).1',
#  'Extent (E).1',
#  'Lomotil',
#  'Dipentum (olsalazine)',
#  'Reason for stopping Dipentum:',
#  'Rowasa enemas (mesalamine enemas)',
#  'Reason for stopping rowasa enemas:',
#  'Canasa suppositories (mesalamine suppositories)',
#  'Reason for stopping canasa suppositories:',
#  'Flagyl (Metronidazole)',
#  'Reason for stopping Flagyl:',
#  'Cipro (Ciprofloxin)',
#  'Reason for stopping Cipro:',
#  'Xifaxin (rifaxamin)',
#  'Reason for stopping Xifaxin:',
#  'Levaquin',
#  'Reason for stopping Levaquin:',
#  'Other Antibiotic:',
#  'Reason for stopping other antibiotic:',
#  'Prednisone',
#  'Reason for stopping Prednisone:',
#  'Highest dose of Prednisone taken (mg):',
#  'Entocort (Budesonide)',
#  'Reason for stopping Entocort:',
#  'Highest dose of Entocort taken (mg):',
#  'Reason for stopping lomotil:',
#  'Imodium',
#  'Solumedrol (Medrol)',
#  'Reason for stopping Solumedrol:',
#  'IV steroids',
#  'Reason for stopping IV steroids:',
#  'Cortenemas, Cortifoam, Proctofoam',
#  'Reason for stopping enemas or foam:',
#  'Azathioprine (Imuran, Azasan)',
#  'Reason for stopping Azathioprine:',
#  'Methotrexate',
#  'Reason for stopping Methotrexate:',
#  'Mercaptopurine (Purinethol, 6MP)',
#  'Reason for stopping Mercaptopurine:',
#  'VSL #3',
#  'Reason for stopping VSL #3:',
#  'FOS',
#  'Reason for stopping FOS:',
#  'Remicade (Infliximab)',
#  'Reason for stopping Remicade:',
#  'Duration of Remicade use (months):',
#  'Humira (Adalimumab)',
#  'Reason for stopping Humira:',
#  'Duration of Humira use (months):',
#  'Reason for stopping Imodium:',
#  'DTO',
#  'Cimzia (Certlizumab)',
#  'Reason for stopping Cimzia:',
#  'Duration of Cimzia use (months):',
#  'Tysabri (Natalizumab)',
#  'Reason for stopping Tysabri:',
#  'Duration of Tysabri use (months):',
#  'Reason for stopping:',
#  'Asacol (mesalamine)',
#  'Reason for stopping Asacol:',
#  'Pentasa (mesalamine)',
#  'Reason for stopping Pentasa:',
#  'Lialda (mesalamine)',
#  'Reason for stopping Lialda:',
#  'Apriso (mesalamine)',
#  'Reason for stopping Apriso:',
#  'Colozal (balasalizide)',
#  'Reason for stopping Colozal:',
#  'Sulfasalizine (Azulfidine)',
#  'Reason for stopping Sulfasalazine:',
#  'If other, explain:',
#  'Type of surgery:',
#  'Type of surgery:.1',
#  'Has subject had an upper or lower endoscopy?',
#  'Has IBD been confirmed by histopathology?',
#  'Has subject undergone any GI-related radiology procedures?',
#  'Procedure',
#  'Procedure.1',
#  'Has subject undergone any GI-related surgeries?',
#  'Type of surgery:.2',
#  'Type of surgery:.3',
#  'Type of surgery:.4',
#  'Disease_course',
#  '2a. Red or sore eyes',
#  '2b. An abscess (collection of puss) in your abdomen (belly)',
#  '2c. An abscess on the buttock or around the anus',
#  '2d. A narrowing of the bowel (a "stricture")',
#  '2e. A fistula (an abdominal connection',
#  '2f. A draining fistula (if you have a fistula to the skin)',
#  '2g. Skin problems',
#  '3a. Fever greater than 100 degrees Fahrenheit',
#  '3b. Fatigue or lack of energy',
#  '3c. Difficulty sleeping',
#  '3d. Nausea',
#  '3e. Vomiting',
#  '3f. Mouth sores',
#  '3g. Back pain',
#  '3h. Night sweats',
#  '3i. Decreased appetite',
#  '3j. Weight loss',
#  'IN THE PAST SIX MONTHS, my disease has been:',
#  '5a. How would you rate your health today with regard to your',
#  '5b. How would you rate your health today with regard to you',
#  'race',
#  'Has the subject undergone any relevant GI imaging procedures (abdomen, pelvis et',
#  'Has the subject been given the C1 kit and asked to collect and submit a sample',
#  'Arthralgias',
#  'Pyoderma gangrenosum.1',
#  'Erythema nodosum.1',
#  'Uveitis.1',
#  'Was SCCAI completed?',
#  'Bowel frequency during the day',
#  'Bowel frequency during the night',
#  'Urgency of defecation',
#  'Blood in the stool',
#  'General well being over the past 24 hours',
#  'sccai',
#  'Screening Status',
#  'Ileum',
#  'Right Colon',
#  'Transverse Colon',
#  'Left Colon',
#  'Rectum',
#  'Total',
#  'Ileum.1',
#  'Right Colon.1',
#  'Transverse Colon.1',
#  'Left Colon.1',
#  'Rectum.1',
#  'Total.1',
#  'Ileum.2',
#  'Right Colon.2',
#  'Transverse Colon.2',
#  'Left Colon.2',
#  'Rectum.2',
#  'Total.2',
#  'Ileum.3',
#  'Right Colon.3',
#  'Transverse Colon.3',
#  'Left Colon.3',
#  'Rectum.3',
#  'Total.3',
#  'SES-CD Score',
#  'Partial Endoscopy.1',
#  'sex',
#  '8. Felt relaxed and free of tension',
#  '9. Troubled by a feeling of having to go to the bathroom',
#  '10. Felt angry as a result of bowel problem',
#  '1. Feeling of fatigue',
#  '2. Delay or cancel a social engagement',
#  '3. Difficulty doing leisure or sports activities',
#  '4. How often during the last 2 weeks have you been troubled by pain in the abdom',
#  '5. How often during the last two weeks have you felt depressed or discouraged? P',
#  '6. Problem with passing large amounts of gas',
#  '7. Problem with weight',
#  'SIBDQ Score',
#  'Specify race',
#  'Was stool sample collected?',
#  'Tube A: DNA/RNA',
#  'Tube A: Metabolomics',
#  'Tube A: Storage',
#  'Tube A:Viromics',
#  'Tube B:Fecal Calprotectin',
#  'fecalcal',
#  'Tube B:Proteomics',
#  'Viromics received at Baylor:',
#  'FecalCal received at MGH:',
#  'Proteomics received at LBNL:',
#  'Stool Sample ID:  Tube A  (EtOH)',
#  'Sample ID: Tube B (No preservative)',
#  'Tube A and B received at Broad:',
#  'stool_id',
#  'smoking status',
#  'Number years smoked',
#  'Age when started smoking',
#  'How many cigarettes/cigars/etc. do you smoke per day?']

# %% [markdown]
# **Important:** We will focus only on the diagnosis groups.

# %%
groups = metadata[['diagnosis']].reset_index().drop_duplicates().set_index('External ID')

# %% [markdown]
# ## Relative Abundance Comparison (Phylum Level) 🦠
#
# To provide an intuitive, high-level view of taxonomic shifts, it is useful to visualize the relative abundance of the major microbial groups (e.g., Phyla) in each diagnostic group.
#
# ### Method: Taxonomic Aggregation and Stacked Bar Plot
#
# This method aggregates the complex species-level data into broader taxonomic categories (Phyla).
#
# 1.  **Taxonomic Aggregation:** The code assumes the column names in your `data` contain the full taxonomic lineage (e.g., `k__Bacteria|p__Firmicutes|c__...`). It extracts the **Phylum level** by splitting the string.
# 2.  **Relative Abundance:** The absolute counts are converted to relative abundances (fractions of the total community) for each sample.
# 3.  **Group Averaging:** The average relative abundance for each Phylum is calculated for the three diagnostic groups (CD, UC, nonIBD).
# 4.  **Stacked Bar Plot:** A stacked bar plot is generated, where the height of the bar is $100\%$ and the segments represent the proportional contribution of each Phylum to the average community in that group.

# %%
import matplotlib.pyplot as plt
import plotly.express as px

# This assumes your taxonomic data is annotated and can be aggregated.
# Assuming the first part of the column name (before the first '|') is the Phylum
phylum_df = data.T.copy()

# Simple aggregation example:
# If you have full taxonomy in columns like 'k__Bacteria|p__Firmicutes;...'
# Use string operations to extract the phylum level:
phylum_df.columns = phylum_df.columns.map(lambda x: x.split('|')[1] if len(x.split('|')) > 1 else 'NA')
phylum_df = phylum_df.drop('NA', axis=1)
phylum_grouped = phylum_df.groupby(by=phylum_df.columns, axis=1).sum()


# Convert to relative abundance (0 to 1)
phylum_rel_abun = phylum_grouped.div(phylum_grouped.sum(axis=1), axis=0)

# Merge with metadata for grouping
plot_rel_abun = phylum_rel_abun.merge(groups, left_index=True, right_index=True)

# 2. Plotting (e.g., showing average composition per group)
plot_data_melted = plot_rel_abun.groupby('diagnosis').mean().T.reset_index().melt(id_vars='index')


# Create the figure
fig = px.bar(
    plot_data_melted,
    x='diagnosis',
    y='value',
    color='index',
    title='Average Relative Abundance of Phyla by Diagnosis',
    labels={
        'diagnosis': 'Diagnosis Group',
        'value': 'Average Relative Abundance',
        'index': 'Phylum'
    },
    barmode='stack'
)

# To save the figure to a file Note: Not currently supported in Colab
fig.write_image('metagenomics/results/Relative_abundance/relative_abundance_phylum.png', scale=3)
fig.write_json('metagenomics/results/Relative_abundance/relative_abundance_phylum.json')
# Out:
# /tmp/ipython-input-1750048188.py:13: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   phylum_grouped = phylum_df.groupby(by=phylum_df.columns, axis=1).sum()

# %%
fig
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="19c0b14f-0096-4000-a8d7-3ebcfd9fb4cb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("19c0b14f-0096-4000-a8d7-3ebcfd9fb4cb")) {                    Plotly.newPlot(                        "19c0b14f-0096-4000-a8d7-3ebcfd9fb4cb",                        [{"alignmentgroup":"True","hovertemplate":"Phylum=p__Acidobacteria\u003cbr\u003eDiagnosis Group=%{x}\u003cbr\u003eAverage Relative Abundance=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"p__Acidobacteria","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"p__Acidobacteria","offsetgroup":"p__Acidobacteria","orientation":"v","showlegend":true,"textposition":"auto","x":["CD","UC","nonIBD"],"xaxis":"x","y":[1.76907945892059e-6,1.180769050846976e-6,1.364894768455343e-6],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Phylum=p__Actinobacteria\u003cbr\u003eDiagnosis Group=%{x}\u003cbr\u003eAverage Relative Abundance=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"p__Actinobacteria","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"p__Actinobacteria","offsetgroup":"p__Actinobacteria","orientation":"v","showlegend":true,"textposition":"auto","x":["CD","UC","nonIBD"],"xaxis":"x","y":[0.008779250958225139,0.01712573464319675,0.011470004680521522],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Phylum=p__Ascomycota\u003cbr\u003eDiagnosis Group=%{x}\u003cbr\u003eAverage Relative Abundance=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"p__Ascomycota","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"p__Ascomycota","offsetgroup":"p__Ascomycota","orientation":"v","showlegend":true,"textposition":"auto","x":["CD","UC","nonIBD"],"xaxis":"x","y":[0.000012980285595836215,2.0256152768892136e-6,1.2822896324415041e-6],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Phylum=p__Bacteroidetes\u003cbr\u003eDiagnosis Group=%{x}\u003cbr\u003eAverage Relative Abundance=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"p__Bacteroidetes","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"p__Bacteroidetes","offsetgroup":"p__Bacteroidetes","orientation":"v","showlegend":true,"textposition":"auto","x":["CD","UC","nonIBD"],"xaxis":"x","y":[0.6097153579092729,0.5851817121424472,0.5854057930413165],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Phylum=p__Chlorobi\u003cbr\u003eDiagnosis Group=%{x}\u003cbr\u003eAverage Relative Abundance=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"p__Chlorobi","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"p__Chlorobi","offsetgroup":"p__Chlorobi","orientation":"v","showlegend":true,"textposition":"auto","x":["CD","UC","nonIBD"],"xaxis":"x","y":[0.0,0.0,2.949293068247338e-7],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Phylum=p__Cyanobacteria\u003cbr\u003eDiagnosis Group=%{x}\u003cbr\u003eAverage Relative Abundance=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"p__Cyanobacteria","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"p__Cyanobacteria","offsetgroup":"p__Cyanobacteria","orientation":"v","showlegend":true,"textposition":"auto","x":["CD","UC","nonIBD"],"xaxis":"x","y":[0.0,1.8779526412245841e-6,0.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Phylum=p__Deinococcus_Thermus\u003cbr\u003eDiagnosis Group=%{x}\u003cbr\u003eAverage Relative Abundance=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"p__Deinococcus_Thermus","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"p__Deinococcus_Thermus","offsetgroup":"p__Deinococcus_Thermus","orientation":"v","showlegend":true,"textposition":"auto","x ...

# %% [markdown]
# ## Alpha Diversity Analysis (Shannon Index)
#
# **Alpha diversity** is a metric used to assess the diversity within a single community (a single sample in this case). The **Shannon diversity index** quantifies the uncertainty in predicting the species identity of an individual randomly selected from a sample. Higher values indicate higher diversity and richness.
#
# ### Method: Shannon Index
#
# The code uses the `scikit-bio` library to:
#
# 1.  **Calculate Shannon Diversity:** Apply the **'shannon' metric** from the `alpha_diversity` function to the sample-by-taxa abundance table.
# 2.  **Merge Data:** Join the calculated diversity scores with the sample diagnosis metadata, preparing the results for statistical comparison and plotting.

# %%
from skbio.diversity.alpha import shannon

alpha_diversity = {}

for col in data.columns:
    alpha_diversity[col] = shannon(data[col], base=2)

alpha_diversity = pd.DataFrame.from_dict(alpha_diversity, orient='index')

# %%
alpha_diversity.head()
# Out:
#                  0
# CSM5FZ4M  4.411125
# CSM5MCUO  5.122843
# CSM5MCVL  4.565702
# CSM5MCVN  4.459389
# CSM5MCW6  3.883694

# %%
groups.head()
# Out:
#             diagnosis
# External ID
# 206615             CD
# 206614             CD
# 206617             CD
# 206619             CD
# 206616             CD

# %%
alpha_diversity_df = pd.DataFrame({
    'Shannon_Diversity': alpha_diversity.iloc[:, 0],
    'Group': [groups.loc[i, 'diagnosis'] for i in alpha_diversity.index]
})
alpha_diversity_df.head()
# Out:
#           Shannon_Diversity Group
# CSM5FZ4M           4.411125    UC
# CSM5MCUO           5.122843    UC
# CSM5MCVL           4.565702    CD
# CSM5MCVN           4.459389    CD
# CSM5MCW6           3.883694    CD

# %% [markdown]
# ## Visualization: Alpha Diversity Comparison
#
# To visually compare the microbial diversity between the different disease groups (**nonIBD**, **CD** (Crohn's Disease), and **UC** (Ulcerative Colitis)), a **boxplot** is generated.
#
# Boxplots are ideal for summarizing the distribution of a continuous variable (**Shannon Diversity**) across multiple categorical groups (**Diagnosis**). This plot will show the median, quartiles, and range of the alpha diversity for each diagnostic group, allowing for a visual assessment of whether IBD is associated with reduced or altered microbial diversity.

# %%
from scipy.stats import mannwhitneyu


# Statistical test for Alpha Diversity between groups
stat, p_alpha = mannwhitneyu(
    alpha_diversity_df[alpha_diversity_df['Group'] == 'CD']['Shannon_Diversity'],
    alpha_diversity_df[alpha_diversity_df['Group'] == 'UC']['Shannon_Diversity']
)

print(f"\n## Alpha Diversity (Shannon) Test")
print(f"Mann-Whitney U P-value: {p_alpha:.4f}")

# Visualization of Alpha Diversity
import plotly.express as px

# Check if p_alpha is defined, otherwise use a placeholder value for the title
try:
    p_value = p_alpha
except NameError:
    p_value = 0.0001 # Placeholder value if p_alpha is not defined

# Create the figure
fig = px.box(
    alpha_diversity_df,
    x='Group',
    y='Shannon_Diversity',
    color='Group',
    title=f'Alpha Diversity (Shannon Index)<br>Mann-Whitney P={p_value:.4f}', # <br> creates a line break
    labels={
        'Group': 'Experimental Group',
        'Shannon_Diversity': 'Shannon Diversity'
    }
)
# To save the figure to a file Note: Not currently supported in Colab
fig.write_image('metagenomics/results/Alpha_diversity/alpha_diversity.png', scale=3)
# Out:
# ## Alpha Diversity (Shannon) Test
# Mann-Whitney U P-value: 0.0349

# %%
fig
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="93f5e5d8-4b75-4fc4-bac9-6d8a3c255ce5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("93f5e5d8-4b75-4fc4-bac9-6d8a3c255ce5")) {                    Plotly.newPlot(                        "93f5e5d8-4b75-4fc4-bac9-6d8a3c255ce5",                        [{"alignmentgroup":"True","hovertemplate":"Experimental Group=%{x}\u003cbr\u003eShannon Diversity=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"UC","marker":{"color":"#636efa"},"name":"UC","notched":false,"offsetgroup":"UC","orientation":"v","showlegend":true,"x":["UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC","UC"],"x0":" ","xaxis":"x","y":[4.411124848163982,5.122842924814604,4.968943603027179,5.223049473165229,4.515148875282417,4.62081949865806,4.777025894876403,4.820179468621186,4.95604897871685,4.842450400239865,4.9382658952958405,4.762872509949169,4.431949747446797,4.954109098052425,4.575252975274765,4.2415497658571635,4.283039102319809,4.032378637899365,4.432812878059744,4.6878145184625755,4.6669425399923155,4.926950337747418,4.6443025621914025,4.658393018566749,4.528767154920682,4.761702680749954,4.856903371954876,4.59424609898766,4.7939368120884716,4.733430146917198,4.862529267717308,5.387914302130904,4.53498512165417,5.074295997534592,5.027775526304936,5.1225520005919245,5.191348316097977,4.934521122790645,4.765912856609395,5.00384449052474,5.180476633491388,4.18606401347782,4.118795236444054,4.120997331418956,4.149447439865826,4.058592956354689,4.4059 ...

# %% [markdown]
# ## Differential Abundance Testing (Taxonomic)
#
# **Differential abundance testing** goes beyond diversity metrics to identify **specific microbial taxa** that are statistically different in relative abundance between two or more groups (e.g., a specific *species* that is higher in CD patients compared to UC patients).
#
# ### Method: Mann-Whitney U Test and FDR Correction
#
# This section uses the **Mann-Whitney U test** (a non-parametric test) to compare the distribution of relative abundances for each taxon between the two defined groups (Crohn's Disease vs. non-IBD control). The Mann-Whitney U test is ideal for this type of data as microbial abundances are often non-normally distributed and contain many zeros.
#
# The code performs the following steps:
#
# 1.  **Define Groups:** Selects sample indices for the two comparison groups ('CD' vs. 'nonIBD').
# 2.  **Iterate and Test:** Iterates through every microbial taxon and calculates the **Mann-Whitney U test** (via `scipy.stats.ranksums` or `scipy.stats.mannwhitneyu`) to get a raw p-value for the difference in abundance.
# 3.  **Multiple Testing Correction (FDR):** The resulting raw p-values are then adjusted using the **Benjamini-Hochberg False Discovery Rate (FDR)** method (`smm.multipletests`). This is a crucial step to control the number of false positives that occur when performing thousands of individual tests.
# 4.  **Reporting:** Taxa with an adjusted p-value (FDR\_P\_Value) below the significance threshold (e.g., $0.05$) are reported as **significantly differentially abundant**.

# %%
# We'll test for taxa significantly different between CD and UC
p_values = {}
for taxa_name in data.index:
    group_a_data = data.loc[taxa_name, list(set(data.columns).intersection(groups[groups['diagnosis'] == 'CD'].index))]
    group_b_data = data.loc[taxa_name, list(set(data.columns).intersection(groups[groups['diagnosis'] == 'UC'].index))]

    # Use Mann-Whitney U test (non-parametric, suitable for non-normal count data)
    stat, p_val = mannwhitneyu(group_a_data, group_b_data, alternative='two-sided')
    p_values[taxa_name] = p_val

# Convert results to DataFrame and apply multiple testing correction (e.g., Benjamini/Hochberg FDR)
diff_taxa_results = pd.DataFrame(list(p_values.items()), columns=['Taxa', 'P_Value'])
from statsmodels.sandbox.stats.multicomp import multipletests
_, corrected_p, _, _ = multipletests(diff_taxa_results['P_Value'], method='fdr_bh')
diff_taxa_results['FDR_P_Value'] = corrected_p

significant_taxa = diff_taxa_results[diff_taxa_results['FDR_P_Value'] < 0.05].sort_values('FDR_P_Value')

print(f"\n## Differential Abundance Test (Mann-Whitney U, FDR_P_Value < 0.05)")
print(f"Found {len(significant_taxa)} significantly different taxa:")
print(significant_taxa.head())
significant_taxa.to_csv('metagenomics/results/Differential_abundance/significant_taxa.csv', index=False)
print("-" * 40)
# Out:
# ## Differential Abundance Test (Mann-Whitney U, FDR_P_Value < 0.05)
# Found 269 significantly different taxa:
#                                                   Taxa       P_Value  \
# 767  k__Bacteria|p__Firmicutes|c__Clostridia|o__Clo...  5.994635e-18
# 766  k__Bacteria|p__Firmicutes|c__Clostridia|o__Clo...  5.994635e-18
# 765  k__Bacteria|p__Firmicutes|c__Clostridia|o__Clo...  2.358778e-16
# 266  k__Bacteria|p__Bacteroidetes|c__Bacteroidia|o_...  8.721310e-14
# 270  k__Bacteria|p__Bacteroidetes|c__Bacteroidia|o_...  1.455894e-13
#
#       FDR_P_Value
# 767  4.433032e-15
# 766  4.433032e-15
# 765  1.162877e-13
# 266  3.224704e-11
# 270  3.588779e-11
# ----------------------------------------

# %% [markdown]
# ## Principal Component Analysis (PCA)
#
# Although **PCoA** (using distances like Bray-Curtis) is standard, **Principal Component Analysis (PCA)** is a robust way to visualize clustering. Use the relative abundance data (Taxa as features, Samples as observations).
#
# ### Method: Principal Component Analysis (PCA)
#
# **PCA** is an **ordination method** primarily used for **dimensionality reduction** on the *raw* or *normalized* **abundance data** itself, not on a distance matrix.
#
#   * **Goal:** To find a set of orthogonal axes (Principal Components, or PCs) that capture the maximum possible **variance** in the *taxa abundances* across all samples.
#   * **Interpretation:** PCA identifies co-varying groups of taxa that are responsible for the differences between samples. An ordination plot would show samples clustered by overall abundance profile, and a **biplot** could show which specific taxa (vectors) drive the separation.

# %%
from sklearn.decomposition import PCA
X = data.T # Transpose: Samples are rows, Taxa are columns

# Run PCA
pca = PCA(n_components=2)
principal_components = pca.fit_transform(X)
pca_df = pd.DataFrame(data=principal_components, columns=['PC1', 'PC2'], index=X.index)
pca_df['Group'] = [groups.loc[i, 'diagnosis'] for i in pca_df.index]

explained_variance = pca.explained_variance_ratio_
pc1_variance = explained_variance[0] * 100
pc2_variance = explained_variance[1] * 100
# Visualization of Beta Diversity
# Create the figure
fig = px.scatter(
    pca_df,
    x='PC1',
    y='PC2',
    color='Group',      # Equivalent to hue
    symbol='Group',     # Equivalent to style
    size_max=10,        # Plotly size is by area, not diameter (s=100 is large).
    opacity=0.8,        # Optional: Add slight transparency
    color_discrete_sequence=px.colors.qualitative.Vivid, # Use a color scheme similar to 'viridis' or a common qualitative one
    title='Beta Diversity Visualization (PCA)',
    labels={
        'PC1': f'PC1 ({pc1_variance:.2f}%)',
        'PC2': f'PC2 ({pc2_variance:.2f}%)',
        'Group': 'Group'
    }
)
# To save the figure to a file Note: Not currently supported in Colab
fig.write_image('metagenomics/results/Principal_component_analysis/pca.png', scale=3)

# %%
fig
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="4e7a3c8a-966e-453b-ae50-45e1e57d7ce7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4e7a3c8a-966e-453b-ae50-45e1e57d7ce7")) {                    Plotly.newPlot(                        "4e7a3c8a-966e-453b-ae50-45e1e57d7ce7",                        [{"hovertemplate":"Group=UC\u003cbr\u003ePC1 (41.84%)=%{x}\u003cbr\u003ePC2 (13.08%)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"UC","marker":{"color":"rgb(229, 134, 6)","opacity":0.8,"symbol":"circle"},"mode":"markers","name":"UC","showlegend":true,"x":[0.6454960789480068,-0.1736945990045223,-0.00839402061752724,-0.13317710339963504,0.6863135176227039,0.6284384438494018,0.513744977460575,-0.7347427724071439,0.3118001033060471,0.4521993520505173,0.17578270865186996,0.4563173510142238,-0.08049168715221781,0.2963879819513535,0.7118911365622734,0.8267056270797372,0.8622375009720997,1.0014779008382286,0.7472208121936048,0.5167825158227567,0.4010942078654363,0.2003979825649716,0.6534860898595553,0.6084289473692946,0.5983335028799927,-0.3330960002371637,-0.23075344708232687,0.6613676383726719,0.49356269051142865,-0.18564736057193995,0.16841152507898804,-0.26611851579876766,0.6572835876961752,-1.1858286039036328,-1.2425270698112987,-0.761235153027762,-1.2147092939658617,0.22788818769684077,0.5326808896110494,0.05509979130511081,-0.22366325180559984,0.901669355160153,0.9559782033961938,0.9706016293758789,0.9279241975837031,0.9441420089839262,0.7283563344484889,-0.34097321676901793,-0.0583117706116105,0.5125672197085313,0.7819838975047873,0.28289684562849454,0.7088200049853731,0.6362288826498107,0.6096991717450805,-0.19938256720045863,-0.8418180174986127,0.04424538945327834,0.060671780526849926,0.40338884343969833,-1.2850305531371762,-0.1616891491714408,0.10616978238392812,0.16286473442515192,0.7564828440708479,0.15250450814796437,0.7812992307518111,0.27142355232983967,0.16833896432884154,0.8736540776758712,0.950126433849593,0.9574485138186029,0.8565889432752809,0.9774147113855769,0.9079549945883101,0.06567427875074988,-0.3752563902628231,-0.7952639176643731,-0.09622528832419605,0.7106886434404092,0.3638477197647484,0.7072598659370757,0.883638308693137,0.675271518892808,0.7854478865537157,0.752877561431806,0.6213074191663124,0.0608017107580423,0.02861977770705337,0.4647944607839682,0.3703881100259893,-0.25532060541184776,0.2049730329508213,0.6706344375971961,0.6089169045638361,0.7512959466153631,0.5895828962853648,0.5890836125119511,0.09725215962195938,-0.27614522184437257,0.6588406624217074,0.8965499948484215,0.8471474231441272,0.29320820846927137,0.5181357771768773,0.8089773368513803,0.1213883042286395,0.26828458571751784,-0.19753943572698254,0.5729379184937644,0.4452750864023052,0.4079389800408607,0.6319484229806681,0.28020646266682564,0.25436491385751975,0.9541084915869271,0.6654053720983937,-0.04246915505995885,0.3679025971335211,0.0055885068001506315,-0.1269938280820229,0.39843530335686045,0.5316035539454965,0.21489645979642436,0.15352397950970953,-0.18564975032486944,0.8628155462321525,0.25029528927702976,-0.09491660441055089,-0.9324006488251958,-0.43170810433333007,-0.19527315907891662,0.221351485288507,0.7903325572796247,0.19310514532331163,-0.08780144829190796,0.45590287854886763,-0.8509051808668388,0.3332200613148546,0.14650615132763928,-0.18771163417030465,-0.3287006270655373,-0.2558113194448938,-0.1667027224256775,-0.8818586282664624,0.8463975325032487,0.44130511927279475,0.4713374550975148,0.3861999811364817,0.6986809296206936,-1.1598680903457346,-1.0443941551819063,-0.6558183816708407,-1.2877894784257298,0.27186664318670717,-0.9006777243337396,0.47080605497109673,-0.8763791272110956,-0.05051508367823236,-0.9380286494733131,-0.962329228300657,-1.0819962 ...

# %% [markdown]
# ## Beta Diversity Analysis: Bray-Curtis and PCoA
#
# **Beta diversity** measures the difference in microbial community composition ***between*** samples. It is used to determine if the microbial community structure differs significantly across groups (e.g., between CD and nonIBD subjects).
#
# ### Method: Bray-Curtis Dissimilarity (Beta Diversity Metric)
#
# The **Bray-Curtis dissimilarity** is an abundance-based **beta diversity metric** that quantifies the difference in microbial composition between two samples. A distance matrix is calculated, where each cell contains the Bray-Curtis distance (0 = identical, 1 = maximally different) between a pair of samples.
#
# ### Method: Principal Coordinate Analysis (PCoA)
#
# **Principal Coordinate Analysis (PCoA)** (also known as Multidimensional Scaling, MDS) is an **ordination method** used to visualize the distances in the Bray-Curtis matrix in a low-dimensional space (typically 2D or 3D).
#
#   * It finds a set of orthogonal axes (Principal Coordinates) that best represent the variation between samples based on the distance matrix.
#   * The output reports the percentage of total variation explained by the first two axes (**PC1** and **PC2**), indicating how much of the original data's variability is captured in the 2D plot.

# %%
import numpy as np
from skbio.stats.ordination import pcoa
from skbio.diversity import beta_diversity

# Calculate Beta-Diversity (Distance Matrix)
# PCoA requires a distance matrix, which is computed using a beta-diversity metric.
# Common metrics are Bray-Curtis, Jaccard, or UniFrac (if you have a phylogenetic tree).
print("--- Calculating Bray-Curtis Distance ---")

# Calculate Bray-Curtis distance
# 'braycurtis' is the metric, samples_taxa_df is the data, sample_ids are the indices
bray_curtis_dm = beta_diversity(
    metric='braycurtis',
    counts=data.T.values,
    ids=data.T.index
)

# bray_curtis_dm is a skbio.stats.distance.DistanceMatrix object
print(f"Distance Matrix Shape: {bray_curtis_dm.shape}\n")


# Perform PCoA
print("--- Performing PCoA ---")

# Run Principal Coordinate Analysis
# The input is the DistanceMatrix object
pcoa_results = pcoa(bray_curtis_dm)

# Access the proportion of variance explained by each axis
explained_variance = pcoa_results.proportion_explained
pc1_variance = explained_variance.iloc[0] * 100
pc2_variance = explained_variance.iloc[1] * 100

print(f"PC1 explains: {pc1_variance:.2f}%")
print(f"PC2 explains: {pc2_variance:.2f}%\n")

# Access the coordinates for plotting
pcoa_coords = pcoa_results.samples
pcoa_coords = pcoa_coords.iloc[:, [0, 1]].rename(columns={
    pcoa_coords.columns[0]: 'PC1',
    pcoa_coords.columns[1]: 'PC2'
})
# Out:
# --- Calculating Bray-Curtis Distance ---
# Distance Matrix Shape: (1638, 1638)
#
# --- Performing PCoA ---
# /usr/local/lib/python3.12/dist-packages/skbio/stats/ordination/_principal_coordinate_analysis.py:157: RuntimeWarning:
#
# EIGH: since no value for dimensions is specified, PCoA for all dimensions will be computed, which may result in long computation time if the original distance matrix is large.
# PC1 explains: 25.56%
# PC2 explains: 9.17%
# /usr/local/lib/python3.12/dist-packages/skbio/stats/ordination/_principal_coordinate_analysis.py:275: RuntimeWarning:
#
# The result contains negative eigenvalues that are large in magnitude, which may suggest result inaccuracy. See Notes for details. The negative-most eigenvalue is -1.5137206528652376 whereas the largest positive one is 63.563217229864264.

# %% [markdown]
# ## Visualization: PCoA Ordination Plot
#
# The final step is to plot the sample coordinates from the PCoA (PC1 vs. PC2) to visualize how the overall microbial communities cluster.
#
# ### Interpretation
#
# By coloring the points on the scatter plot according to the sample's **Diagnosis** (CD, UC, nonIBD), we can visually assess the **beta diversity**. If samples from the same diagnostic group cluster together and are separate from other groups, it suggests that the disease is a major factor shaping

# %%
# Merge the PCoA coordinates with the sample metadata
plot_data = pcoa_coords.join(groups)
plot_column = 'diagnosis' # The metadata column to color the plot by

# Plotting with Matplotlib/Seaborn
print("--- Plotting PCoA Results ---")

fig = px.scatter(
    plot_data,
    x='PC1',
    y='PC2',
    color=plot_column,      # Equivalent to hue
    symbol=plot_column,     # Equivalent to style
    size_max=10,             # Plotly size is by area, not diameter (s=100 is large for Seaborn)
    opacity=0.8,             # Optional: add slight transparency to points
    title=f'PCoA of Samples (Bray-Curtis Distance), Colored by {plot_column}',
    labels={
        'PC1': f'PC1 ({pc1_variance:.2f}%)',
        'PC2': f'PC2 ({pc2_variance:.2f}%)',
        plot_column: plot_column # Ensures the legend title is correct
    }
)
# To save the figure to a file Note: Not currently supported in Colab
fig.write_image('metagenomics/results/PCoA/PCoA.png', scale=3)
# Out:
# --- Plotting PCoA Results ---

# %%
fig
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="35e6b1ef-98cd-4cdd-b10a-198946a79352" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("35e6b1ef-98cd-4cdd-b10a-198946a79352")) {                    Plotly.newPlot(                        "35e6b1ef-98cd-4cdd-b10a-198946a79352",                        [{"hovertemplate":"diagnosis=UC\u003cbr\u003ePC1 (25.56%)=%{x}\u003cbr\u003ePC2 (9.17%)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"UC","marker":{"color":"#636efa","opacity":0.8,"symbol":"circle"},"mode":"markers","name":"UC","showlegend":true,"x":[0.1978482015669761,-0.06593615734458404,0.003761177858610484,-0.06127988883724787,0.20379233622340948,0.1926111730695864,0.1658307792473984,-0.22238362715293025,0.1079673945146251,0.14178020806572905,0.06861850144636249,0.15093245605149,0.0005273917910985442,0.1022926659528792,0.2109431470880412,0.2451638654966346,0.2509658294974606,0.2748655611843669,0.2226553528760567,0.16869186133091363,0.13065067678902686,0.07473236845303885,0.20204907005051068,0.18320467385363398,0.17128591238740598,-0.11657240995743358,-0.09114066497762165,0.188321184451878,0.16307363385355927,-0.04884888319913509,0.06245080435459473,-0.06964082812645603,0.22058702488071577,-0.3863469191388401,-0.4025666711407757,-0.2484544442434702,-0.398838847889257,0.07042642756019689,0.16343037154504514,0.013013719654840258,-0.0784336098306502,0.25769488133130475,0.27142303803177503,0.2717085702381128,0.2611489913534387,0.26051122470271754,0.2276300807362387,-0.10627033108362487,-0.014839480629878306,0.14816771191220132,0.22455756912403627,0.0949089705103341,0.199922094064681,0.18871902036627186,0.20229365618813488,-0.06262607173532445,-0.2701694575602773,0.015233480070697237,0.015345770649469829,0.1292077226426255,-0.3442206724059255,-0.05145895649932667,0.033663977166997906,0.055071059924694764,0.24143597166848485,0.08099893898417486,0.2228112563412399,0.11300843986053957,0.08611230867743963,0.25181073933767406,0.26761851180830704,0.2673594554875036,0.24849039117315766,0.2678166528973701,0.2572678147239418,0.013508873306867463,-0.13825791650120997,-0.2733497141113481,-0.03215881178522882,0.22532944883309286,0.11775763885030123,0.20629056549807637,0.2544810474762541,0.20218889214190022,0.23427865889633512,0.21667651293838874,0.19336716972477092,0.014082274746838824,-0.0029648125768632393,0.14256995288509428,0.11054226751626425,-0.0666091772119817,0.07359724777498883,0.20470473056460448,0.20510894562945461,0.2052485969990941,0.17550127015611042,0.18866596824252876,0.024625713501205692,-0.10118748901395978,0.2386834971275808,0.2683996892076819,0.2545091365555371,0.07998922742311562,0.14211331848892594,0.21840776756995506,0.022351035065485518,0.07882527700068961,-0.06473973336358199,0.1726860792204858,0.1793474521314753,0.15807690858344625,0.21367713862766385,0.07565030329909117,0.05978644334692384,0.2537096383501215,0.1960621703764755,-0.0018276500107248944,0.13322773185900524,0.009006217228537951,-0.02740711042780538,0.1359631936759624,0.14394362240884703,0.07441470367474619,0.06491516725350789,-0.07230390778828047,0.23980656456323066,0.059812030924806504,-0.03718156375791936,-0.2911281563533074,-0.16381988450975948,-0.08394631734828789,0.0709023272220801,0.21695363230962064,0.06627765816291145,-0.038875119552289214,0.13408716972799595,-0.28627788936595605,0.10251581700792332,0.056551371757895735,-0.07520180387376496,-0.11960211116385024,-0.1056833928744919,-0.06465324473867114,-0.3279152622793635,0.239129351268918,0.15639977101799685,0.14787298724719397,0.13398383310094308,0.21144603773651005,-0.34571833085683135,-0.3249480749845408,-0.21281970691467228,-0.3907306580931252,0.09208326714432903,-0.297822045837268,0.13771319688021288,-0.2832948354855102,-0 ...

# %% [markdown]
# ## Statistical Validation: Beta Diversity (PERMANOVA) 🔬
#
# While the PCoA plot provides a visual representation of how the microbial communities cluster, **PERMANOVA** (Permutational Multivariate Analysis of Variance) provides the statistical test to confirm if the observed differences between the groups are significant.
#
# ### Method: PERMANOVA (Permutational Multivariate Analysis of Variance)
#
# **PERMANOVA** is the standard non-parametric test used in microbial ecology to test for significant differences in community composition (**beta diversity**) among groups.
#
#   * **Input:** The **Bray-Curtis distance matrix** (calculated earlier) and the **categorical grouping variable** (the 'diagnosis' column).
#   * **Mechanism:** It works by partitioning the variation in the distance matrix and comparing the observed variation *between* groups to the expected variation by randomly permuting the sample labels a large number of times (e.g., 999 permutations).
#   * **Output:** A statistical test result, including an **$F$-statistic** and a **$p$-value**. A $p$-value less than $0.05$ indicates that the microbial community composition is significantly different across the diagnostic groups.

# %%
# PERMANOVA requires the DistanceMatrix and the metadata
from skbio.stats.distance import permanova

# Run PERMANOVA on the Bray-Curtis distance matrix using the 'diagnosis' column
results_permanova = permanova(
    distance_matrix=bray_curtis_dm,
    grouping=groups['diagnosis'],
    permutations=999 # Use 999 permutations for robust p-value
)

print("\n--- PERMANOVA Test Results (Beta Diversity) ---")
print(results_permanova)

permanova_results_df = pd.DataFrame({
    'Test': ['PERMANOVA'],
    'F-Statistic': [results_permanova['test statistic']],
    'P-Value': [results_permanova['p-value']],
    'Permutations': [results_permanova['number of permutations']]
})
permanova_results_df.to_csv('metagenomics/results/PERMANOVA/permanova_results.csv', index=False)
# Check the P-value to determine if groups are significantly separated
if results_permanova['p-value'] < 0.05:
    print("\nResult: The microbial communities (Bray-Curtis) are significantly different across the diagnosis groups (CD, UC, nonIBD).")
else:
    print("\nResult: No significant difference found in microbial communities across groups.")
# Out:
# --- PERMANOVA Test Results (Beta Diversity) ---
# method name               PERMANOVA
# test statistic name        pseudo-F
# sample size                    1638
# number of groups                  3
# test statistic            13.775617
# p-value                       0.001
# number of permutations          999
# Name: PERMANOVA results, dtype: object
#
# Result: The microbial communities (Bray-Curtis) are significantly different across the diagnosis groups (CD, UC, nonIBD).

# %% [markdown]
# ## Saving Outputs to Gooogle Drive

# %%
#from google.colab import drive
#drive.mount('/content/drive')

# %%
#!cp -r metagenomics/ /content/drive/MyDrive/

# %% [markdown]
# # Generating a Report

# %%
from vuegen import report_generator

# Generate the report

report_type = "html"

report_dir, config_path = report_generator.get_report(

    dir_path='metagenomics/results', report_type=report_type, logger=None

)

print(f"\nReport generated in {report_dir}")

print(f"\nConfig file generated in {config_path}")
# Out:
# [2025-11-13 11:53:58,224] vuegen: INFO - Path to log file: logs/2025-11-13_11-53-58_report.log
# INFO:vuegen:Path to log file: logs/2025-11-13_11-53-58_report.log
# [2025-11-13 11:53:58,239] vuegen: INFO - Configuration file generated at results_config.yaml
# INFO:vuegen:Configuration file generated at results_config.yaml
# [2025-11-13 11:53:58,258] vuegen: INFO - Report 'Results' initialized with 6 sections.
# INFO:vuegen:Report 'Results' initialized with 6 sections.
# [2025-11-13 11:53:58,260] vuegen: INFO - running in a normal Python process
# INFO:vuegen:running in a normal Python process
# [2025-11-13 11:53:58,262] vuegen: DEBUG - env_vars (QuartoReport): environ({'SHELL': '/bin/bash', 'NV_LIBCUBLAS_VERSION': '12.5.3.2-1', 'NVIDIA_VISIBLE_DEVICES': 'all', 'COLAB_JUPYTER_TRANSPORT': 'ipc', 'NV_NVML_DEV_VERSION': '12.5.82-1', 'NV_CUDNN_PACKAGE_NAME': 'libcudnn9-cuda-12', 'CGROUP_MEMORY_EVENTS': '/sys/fs/cgroup/memory.events /var/colab/cgroup/jupyter-children/memory.events', 'NV_LIBNCCL_DEV_PACKAGE': 'libnccl-dev=2.22.3-1+cuda12.5', 'NV_LIBNCCL_DEV_PACKAGE_VERSION': '2.22.3-1', 'VM_GCE_METADATA_HOST': '169.254.169.253', 'MODEL_PROXY_HOST': 'https://mp.kaggle.net', 'HOSTNAME': 'd576e17d9aa9', 'LANGUAGE': 'en_US', 'TBE_RUNTIME_ADDR': '172.28.0.1:8011', 'COLAB_TPU_1VM': '', 'GCE_METADATA_TIMEOUT': '3', 'NVIDIA_REQUIRE_CUDA': 'cuda>=12.5 brand=unknown,driver>=470,driver<471 brand=grid,driver>=470,driver<471 brand=tesla,driver>=470,driver<471 brand=nvidia,driver>=470,driver<471 brand=quadro,driver>=470,driver<471 brand=quadrortx,driver>=470,driver<471 brand=nvidiartx,driver>=470,driver<471 brand=vapps,driver>=470,driver<471 brand=vpc,driver>=470,driver<471 brand=vcs,driver>=470,driver<471 brand=vws,driver>=470,driver<471 brand=cloudgaming,driver>=470,driver<471 brand=unknown,driver>=535,driver<536 brand=grid,driver>=535,driver<536 brand=tesla,driver>=535,driver<536 brand=nvidia,driver>=535,driver<536 brand=quadro,driver>=535,driver<536 brand=quadrortx,driver>=535,driver<536 brand=nvidiartx,driver>=535,driver<536 brand=vapps,driver>=535,driver<536 brand=vpc,driver>=535,driver<536 brand=vcs,driver>=535,driver<536 brand=vws,driver>=535,driver<536 brand=cloudgaming,driver>=535,driver<536 brand=unknown,driver>=550,driver<551 brand=grid,driver>=550,driver<551 brand=tesla,driver>=550,driver<551 brand=nvidia,driver>=550,driver<551 brand=quadro,driver>=550,driver<551 brand=quadrortx,driver>=550,driver<551 brand=nvidiartx,driver>=550,driver<551 brand=vapps,driver>=550,driver<551 brand=vpc,driver>=550,driver<551 brand=vcs,driver>=550,driver<551 brand=vws,driver>=550,driver<551 brand=cloudgaming,driver>=550,driver<551', 'NV_LIBCUBLAS_DEV_PACKAGE': 'libcublas-dev-12-5=12.5.3.2-1', 'NV_NVTX_VERSION': '12.5.82-1', 'COLAB_JUPYTER_IP': '172.28.0.12', 'NV_CUDA_CUDART_DEV_VERSION': '12.5.82-1', 'NV_LIBCUSPARSE_VERSION': '12.5.1.3-1', 'COLAB_LANGUAGE_SERVER_PROXY_ROOT_URL': 'http://172.28.0.1:8013/', 'NV_LIBNPP_VERSION': '12.3.0.159-1', 'NCCL_VERSION': '2.22.3-1', 'KMP_LISTEN_PORT': '6000', 'TF_FORCE_GPU_ALLOW_GROWTH': 'true', 'ENV': '/root/.bashrc', 'PWD': '/', 'TBE_EPHEM_CREDS_ADDR': '172.28.0.1:8009', 'COLAB_LANGUAGE_SERVER_PROXY_REQUEST_TIMEOUT': '30s', 'TBE_CREDS_ADDR': '172.28.0.1:8008', 'NV_CUDNN_PACKAGE': 'libcudnn9-cuda-12=9.2.1.18-1', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'COLAB_JUPYTER_TOKEN': '', 'LAST_FORCED_REBUILD': '20250623', 'NV_NVPROF_DEV_PACKAGE': 'cuda-nvprof-12-5=12.5.82-1', 'NV_LIBNPP_PACKAGE': 'libnpp-12-5=12.3.0.159-1', 'NV_LIBNCCL_DEV_PACKAGE_NAME': 'libnccl-dev', 'TCLLIBPATH': '/usr/share/tcltk/tcllib1.20', 'NV_LIBCUBLAS_DEV_VERSION': '12.5.3.2-1', 'NVIDIA_PRODUCT_NAME': 'CUDA', 'COLAB_KERNEL_MANAGER_PROXY_HOST': '172.28.0.12', 'UV_BUILD_CONSTRAINT': '', 'NV_LIBCUBLAS_DEV_PACKAGE_NAME': 'libcublas-dev-12-5', 'NV_CUDA_CUDART_VERSION': '12.5.82-1', 'COLAB_WARMUP_DEFAULTS': '1', 'HOME': '/root', 'LANG': 'en_US.UTF-8', 'CUDA_VERSION': '12.5.1', 'CLOUDSDK_CONFIG': '/content/.config', 'NV_LIBCUBLAS_PACKAGE': 'libcublas-12-5=12.5.3.2-1', 'NV_CUDA_NSIGHT_COMPUTE_DEV_PACKAGE': 'cuda-nsight-compute-12-5=12.5.1-1', 'UV_SYSTEM_PYTHON': 'true', 'COLAB_RELEASE_TAG': 'release-colab-external_20251111-060040_RC00', 'KMP_TARGET_PORT': '9000', 'KMP_EXTRA_ARGS': '--logtostderr --listen_host=172.28.0.12 --target_host=172.28.0.12 --tunnel_background_save_url=https://colab.research.google.com/tun/m/cc48301118ce562b961b3c22d803539adc1e0c19/m-s-do6voc6izzh7 --tunnel_background_save_delay=10s --tunnel_periodic_background_save_frequency=30m0s --enable_output_coalescing=true --output_coalescing_required=true ', 'UV_INSTALL_DIR':  ...
# DEBUG:vuegen:env_vars (QuartoReport): environ({'SHELL': '/bin/bash', 'NV_LIBCUBLAS_VERSION': '12.5.3.2-1', 'NVIDIA_VISIBLE_DEVICES': 'all', 'COLAB_JUPYTER_TRANSPORT': 'ipc', 'NV_NVML_DEV_VERSION': '12.5.82-1', 'NV_CUDNN_PACKAGE_NAME': 'libcudnn9-cuda-12', 'CGROUP_MEMORY_EVENTS': '/sys/fs/cgroup/memory.events /var/colab/cgroup/jupyter-children/memory.events', 'NV_LIBNCCL_DEV_PACKAGE': 'libnccl-dev=2.22.3-1+cuda12.5', 'NV_LIBNCCL_DEV_PACKAGE_VERSION': '2.22.3-1', 'VM_GCE_METADATA_HOST': '169.254.169.253', 'MODEL_PROXY_HOST': 'https://mp.kaggle.net', 'HOSTNAME': 'd576e17d9aa9', 'LANGUAGE': 'en_US', 'TBE_RUNTIME_ADDR': '172.28.0.1:8011', 'COLAB_TPU_1VM': '', 'GCE_METADATA_TIMEOUT': '3', 'NVIDIA_REQUIRE_CUDA': 'cuda>=12.5 brand=unknown,driver>=470,driver<471 brand=grid,driver>=470,driver<471 brand=tesla,driver>=470,driver<471 brand=nvidia,driver>=470,driver<471 brand=quadro,driver>=470,driver<471 brand=quadrortx,driver>=470,driver<471 brand=nvidiartx,driver>=470,driver<471 brand=vapps,driver>=470,driver<471 brand=vpc,driver>=470,driver<471 brand=vcs,driver>=470,driver<471 brand=vws,driver>=470,driver<471 brand=cloudgaming,driver>=470,driver<471 brand=unknown,driver>=535,driver<536 brand=grid,driver>=535,driver<536 brand=tesla,driver>=535,driver<536 brand=nvidia,driver>=535,driver<536 brand=quadro,driver>=535,driver<536 brand=quadrortx,driver>=535,driver<536 brand=nvidiartx,driver>=535,driver<536 brand=vapps,driver>=535,driver<536 brand=vpc,driver>=535,driver<536 brand=vcs,driver>=535,driver<536 brand=vws,driver>=535,driver<536 brand=cloudgaming,driver>=535,driver<536 brand=unknown,driver>=550,driver<551 brand=grid,driver>=550,driver<551 brand=tesla,driver>=550,driver<551 brand=nvidia,driver>=550,driver<551 brand=quadro,driver>=550,driver<551 brand=quadrortx,driver>=550,driver<551 brand=nvidiartx,driver>=550,driver<551 brand=vapps,driver>=550,driver<551 brand=vpc,driver>=550,driver<551 brand=vcs,driver>=550,driver<551 brand=vws,driver>=550,driver<551 brand=cloudgaming,driver>=550,driver<551', 'NV_LIBCUBLAS_DEV_PACKAGE': 'libcublas-dev-12-5=12.5.3.2-1', 'NV_NVTX_VERSION': '12.5.82-1', 'COLAB_JUPYTER_IP': '172.28.0.12', 'NV_CUDA_CUDART_DEV_VERSION': '12.5.82-1', 'NV_LIBCUSPARSE_VERSION': '12.5.1.3-1', 'COLAB_LANGUAGE_SERVER_PROXY_ROOT_URL': 'http://172.28.0.1:8013/', 'NV_LIBNPP_VERSION': '12.3.0.159-1', 'NCCL_VERSION': '2.22.3-1', 'KMP_LISTEN_PORT': '6000', 'TF_FORCE_GPU_ALLOW_GROWTH': 'true', 'ENV': '/root/.bashrc', 'PWD': '/', 'TBE_EPHEM_CREDS_ADDR': '172.28.0.1:8009', 'COLAB_LANGUAGE_SERVER_PROXY_REQUEST_TIMEOUT': '30s', 'TBE_CREDS_ADDR': '172.28.0.1:8008', 'NV_CUDNN_PACKAGE': 'libcudnn9-cuda-12=9.2.1.18-1', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'COLAB_JUPYTER_TOKEN': '', 'LAST_FORCED_REBUILD': '20250623', 'NV_NVPROF_DEV_PACKAGE': 'cuda-nvprof-12-5=12.5.82-1', 'NV_LIBNPP_PACKAGE': 'libnpp-12-5=12.3.0.159-1', 'NV_LIBNCCL_DEV_PACKAGE_NAME': 'libnccl-dev', 'TCLLIBPATH': '/usr/share/tcltk/tcllib1.20', 'NV_LIBCUBLAS_DEV_VERSION': '12.5.3.2-1', 'NVIDIA_PRODUCT_NAME': 'CUDA', 'COLAB_KERNEL_MANAGER_PROXY_HOST': '172.28.0.12', 'UV_BUILD_CONSTRAINT': '', 'NV_LIBCUBLAS_DEV_PACKAGE_NAME': 'libcublas-dev-12-5', 'NV_CUDA_CUDART_VERSION': '12.5.82-1', 'COLAB_WARMUP_DEFAULTS': '1', 'HOME': '/root', 'LANG': 'en_US.UTF-8', 'CUDA_VERSION': '12.5.1', 'CLOUDSDK_CONFIG': '/content/.config', 'NV_LIBCUBLAS_PACKAGE': 'libcublas-12-5=12.5.3.2-1', 'NV_CUDA_NSIGHT_COMPUTE_DEV_PACKAGE': 'cuda-nsight-compute-12-5=12.5.1-1', 'UV_SYSTEM_PYTHON': 'true', 'COLAB_RELEASE_TAG': 'release-colab-external_20251111-060040_RC00', 'KMP_TARGET_PORT': '9000', 'KMP_EXTRA_ARGS': '--logtostderr --listen_host=172.28.0.12 --target_host=172.28.0.12 --tunnel_background_save_url=https://colab.research.google.com/tun/m/cc48301118ce562b961b3c22d803539adc1e0c19/m-s-do6voc6izzh7 --tunnel_background_save_delay=10s --tunnel_periodic_background_save_frequency=30m0s --enable_output_coalescing=true --output_coalescing_required=true ', 'UV_INSTALL_DIR': '/usr/local/bin', 'NV_LIBNPP_ ...
# [2025-11-13 11:53:58,265] vuegen: DEBUG - PATH: /opt/bin:/usr/local/nvidia/bin:/usr/local/cuda/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/tools/node/bin:/tools/google-cloud-sdk/bin
# DEBUG:vuegen:PATH: /opt/bin:/usr/local/nvidia/bin:/usr/local/cuda/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/tools/node/bin:/tools/google-cloud-sdk/bin
# [2025-11-13 11:53:58,266] vuegen: DEBUG - sys.path: ['/content', '/env/python', '/usr/lib/python312.zip', '/usr/lib/python3.12', '/usr/lib/python3.12/lib-dynload', '', '/usr/local/lib/python3.12/dist-packages', '/usr/lib/python3/dist-packages', '/usr/local/lib/python3.12/dist-packages/IPython/extensions', '/root/.ipython']
# DEBUG:vuegen:sys.path: ['/content', '/env/python', '/usr/lib/python312.zip', '/usr/lib/python3.12', '/usr/lib/python3.12/lib-dynload', '', '/usr/local/lib/python3.12/dist-packages', '/usr/lib/python3/dist-packages', '/usr/local/lib/python3.12/dist-packages/IPython/extensions', '/root/.ipython']
# [2025-11-13 11:53:58,269] vuegen: DEBUG - Generating 'html' report in directory: '/content/quarto_report'
# DEBUG:vuegen:Generating 'html' report in directory: '/content/quarto_report'
# [2025-11-13 11:53:58,270] vuegen: DEBUG - Created output directory: '/content/quarto_report'
# DEBUG:vuegen:Created output directory: '/content/quarto_report'
# [2025-11-13 11:53:58,272] vuegen: INFO - Created output directory for static content: 'quarto_report/static'
# INFO:vuegen:Created output directory for static content: 'quarto_report/static'
# [2025-11-13 11:53:58,275] vuegen: INFO - Starting to generate sections for the report.
# INFO:vuegen:Starting to generate sections for the report.
# [2025-11-13 11:53:58,277] vuegen: DEBUG - Processing section: 'Alpha Diversity' - 0 subsection(s)
# DEBUG:vuegen:Processing section: 'Alpha Diversity' - 0 subsection(s)
# [2025-11-13 11:53:58,278] vuegen: DEBUG - Adding components of section folder to the report.
# DEBUG:vuegen:Adding components of section folder to the report.
# [2025-11-13 11:53:58,279] vuegen: DEBUG - component_imports: []
# DEBUG:vuegen:component_imports: []
# [2025-11-13 11:53:58,282] vuegen: INFO - Successfully generated content for plot: 'Alpha Diversity'
# INFO:vuegen:Successfully generated content for plot: 'Alpha Diversity'
# [2025-11-13 11:53:58,283] vuegen: WARNING - No subsections found in section: 'Alpha Diversity'. To show content in the report, add subsections to the section.
# WARNING:vuegen:No subsections found in section: 'Alpha Diversity'. To show content in the report, add subsections to the section.
# [2025-11-13 11:53:58,285] vuegen: DEBUG - Processing section: 'Differential Abundance' - 0 subsection(s)
# DEBUG:vuegen:Processing section: 'Differential Abundance' - 0 subsection(s)
# [2025-11-13 11:53:58,286] vuegen: DEBUG - Adding components of section folder to the report.
# DEBUG:vuegen:Adding components of section folder to the report.
# [2025-11-13 11:53:58,287] vuegen: DEBUG - component_imports: ['import pandas as pd', 'from itables import show, init_notebook_mode', 'init_notebook_mode(all_interactive=True)']
# DEBUG:vuegen:component_imports: ['import pandas as pd', 'from itables import show, init_notebook_mode', 'init_notebook_mode(all_interactive=True)']
# [2025-11-13 11:53:58,291] vuegen: INFO - Successfully generated content for DataFrame: 'Significant Taxa'
# INFO:vuegen:Successfully generated content for DataFrame: 'Significant Taxa'
# [2025-11-13 11:53:58,292] vuegen: WARNING - No subsections found in section: 'Differential Abundance'. To show content in the report, add subsections to the section.
# WARNING:vuegen:No subsections found in section: 'Differential Abundance'. To show content in the report, add subsections to the section.
# [2025-11-13 11:53:58,294] vuegen: DEBUG - Processing section: 'Pcoa' - 0 subsection(s)
# DEBUG:vuegen:Processing section: 'Pcoa' - 0 subsection(s)
# [2025-11-13 11:53:58,295] vuegen: DEBUG - Adding components of section folder to the report.
# DEBUG:vuegen:Adding components of section folder to the report.
# [2025-11-13 11:53:58,297] vuegen: DEBUG - component_imports: []
# DEBUG:vuegen:component_imports: []
# [2025-11-13 11:53:58,298] vuegen: INFO - Successfully generated content for plot: 'Pcoa'
# INFO:vuegen:Successfully generated content for plot: 'Pcoa'
# [2025-11-13 11:53:58,301] vuegen: WARNING - No subsections found in section: 'Pcoa'. To show content in the report, add subsections to the section.
# WARNING:vuegen:No subsections found in section: 'Pcoa'. To show content in the report, add subsections to the section.
# [2025-11-13 11:53:58,302] vuegen: DEBUG - Processing section: 'Permanova' - 0 subsection(s)
# DEBUG:vuegen:Processing section: 'Permanova' - 0 subsection(s)
# [2025-11-13 11:53:58,304] vuegen: DEBUG - Adding components of section folder to the report.
# DEBUG:vuegen:Adding components of section folder to the report.
# [2025-11-13 11:53:58,305] vuegen: DEBUG - component_imports: ['import pandas as pd', 'from itables import show, init_notebook_mode', 'init_notebook_mode(all_interactive=True)']
# DEBUG:vuegen:component_imports: ['import pandas as pd', 'from itables import show, init_notebook_mode', 'init_notebook_mode(all_interactive=True)']
# [2025-11-13 11:53:58,310] vuegen: INFO - Successfully generated content for DataFrame: 'Permanova Results'
# INFO:vuegen:Successfully generated content for DataFrame: 'Permanova Results'
# [2025-11-13 11:53:58,311] vuegen: WARNING - No subsections found in section: 'Permanova'. To show content in the report, add subsections to the section.
# WARNING:vuegen:No subsections found in section: 'Permanova'. To show content in the report, add subsections to the section.
# [2025-11-13 11:53:58,312] vuegen: DEBUG - Processing section: 'Principal Component Analysis' - 0 subsection(s)
# DEBUG:vuegen:Processing section: 'Principal Component Analysis' - 0 subsection(s)
# [2025-11-13 11:53:58,315] vuegen: DEBUG - Adding components of section folder to the report.
# DEBUG:vuegen:Adding components of section folder to the report.
# [2025-11-13 11:53:58,318] vuegen: DEBUG - component_imports: []
# DEBUG:vuegen:component_imports: []
# [2025-11-13 11:53:58,320] vuegen: INFO - Successfully generated content for plot: 'Pca'
# INFO:vuegen:Successfully generated content for plot: 'Pca'
# [2025-11-13 11:53:58,321] vuegen: WARNING - No subsections found in section: 'Principal Component Analysis'. To show content in the report, add subsections to the section.
# WARNING:vuegen:No subsections found in section: 'Principal Component Analysis'. To show content in the report, add subsections to the section.
# [2025-11-13 11:53:58,323] vuegen: DEBUG - Processing section: 'Relative Abundance' - 0 subsection(s)
# DEBUG:vuegen:Processing section: 'Relative Abundance' - 0 subsection(s)
# [2025-11-13 11:53:58,325] vuegen: DEBUG - Adding components of section folder to the report.
# DEBUG:vuegen:Adding components of section folder to the report.
# [2025-11-13 11:53:58,326] vuegen: DEBUG - component_imports: ['import plotly.io as pio', 'import requests', 'import json']
# DEBUG:vuegen:component_imports: ['import plotly.io as pio', 'import requests', 'import json']
# [2025-11-13 11:53:58,329] vuegen: INFO - Successfully generated content for plot: 'Relative Abundance Phylum'
# INFO:vuegen:Successfully generated content for plot: 'Relative Abundance Phylum'
# [2025-11-13 11:53:58,330] vuegen: DEBUG - component_imports: []
# DEBUG:vuegen:component_imports: []
# [2025-11-13 11:53:58,332] vuegen: INFO - Successfully generated content for plot: 'Relative Abundance Phylum'
# INFO:vuegen:Successfully generated content for plot: 'Relative Abundance Phylum'
# [2025-11-13 11:53:58,334] vuegen: WARNING - No subsections found in section: 'Relative Abundance'. To show content in the report, add subsections to the section.
# WARNING:vuegen:No subsections found in section: 'Relative Abundance'. To show content in the report, add subsections to the section.
# [2025-11-13 11:53:58,337] vuegen: INFO - Created qmd script to render the app: /content/quarto_report/quarto_report.qmd
# INFO:vuegen:Created qmd script to render the app: /content/quarto_report/quarto_report.qmd
# [2025-11-13 11:53:58,340] vuegen: INFO - Running 'Results' 'html' report with ['quarto', 'render', '/content/quarto_report/quarto_report.qmd']
# INFO:vuegen:Running 'Results' 'html' report with ['quarto', 'render', '/content/quarto_report/quarto_report.qmd']
# [2025-11-13 11:54:18,598] vuegen: INFO - 'Results' 'html' report rendered
# INFO:vuegen:'Results' 'html' report rendered
# Report generated in quarto_report
#
# Config file generated in results_config.yaml
